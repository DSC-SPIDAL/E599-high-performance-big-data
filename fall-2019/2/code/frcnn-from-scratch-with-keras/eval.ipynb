# %% [markdown]
# # initial setup

# %%
ssh r-001
# Out:
#   File "<ipython-input-1-40e8b1e3109e>", line 1
#     ssh r-001
#         ^
# SyntaxError: invalid syntax

# %%
from __future__ import division
import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"
import cv2
import numpy as np
import sys
import pickle
from optparse import OptionParser
import time
from keras_frcnn import config
from keras import backend as K
from keras.layers import Input
from keras.models import Model
from keras_frcnn import roi_helpers
from keras_frcnn.pascal_voc import pascal_voc_util
from keras_frcnn.pascal_voc_parser import get_data
from keras_frcnn import data_generators

from utils import get_bbox
# Out:
# Using TensorFlow backend.

# %%
config_output_filename = "config.pickle"

with open(config_output_filename, 'rb') as f_in:
	C = pickle.load(f_in)
C.network = 'resnet50'
from keras_frcnn import resnet as nn

# %%
img_path = "/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages"
# Method to transform the coordinates of the bounding box to its original size
def get_real_coordinates(ratio, x1, y1, x2, y2):
	real_x1 = int(round(x1 // ratio))
	real_y1 = int(round(y1 // ratio))
	real_x2 = int(round(x2 // ratio))
	real_y2 = int(round(y2 // ratio))

	return (real_x1, real_y1, real_x2 ,real_y2)
def format_img_size(img, C):
	""" formats the image size based on config """
	img_min_side = float(C.im_size)
	(height,width,_) = img.shape
		
	if width <= height:
		ratio = img_min_side/width
		new_height = int(ratio * height)
		new_width = int(img_min_side)
	else:
		ratio = img_min_side/height
		new_width = int(ratio * width)
		new_height = int(img_min_side)
	img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_CUBIC)
	return img, ratio	

def format_img_channels(img, C):
	""" formats the image channels based on config """
	img = img[:, :, (2, 1, 0)]
	img = img.astype(np.float32)
	img[:, :, 0] -= C.img_channel_mean[0]
	img[:, :, 1] -= C.img_channel_mean[1]
	img[:, :, 2] -= C.img_channel_mean[2]
	img /= C.img_scaling_factor
	img = np.transpose(img, (2, 0, 1))
	img = np.expand_dims(img, axis=0)
	return img

def format_img(img, C):
	""" formats an image for model prediction based on config """
	img, ratio = format_img_size(img, C)
	img = format_img_channels(img, C)
	return img, ratio

class_mapping = C.class_mapping

if 'bg' not in class_mapping:
	class_mapping['bg'] = len(class_mapping)

class_mapping = {v: k for k, v in class_mapping.items()}

class_to_color = {class_mapping[v]: np.random.randint(0, 255, 3) for v in class_mapping}
C.num_rois = int(32)

num_features = 1024
print(class_mapping)
# Out:
# {0: 'car\n', 1: 'car', 2: 'bg'}

# %%
! ls models
# Out:
# resnet50  rpn

# %%
C.model_path = "/N/u/imtiazahmad/frcnn-from-scratch-with-keras/models/resnet50/voc.hdf5"

# %% [markdown]
# # setup model

# %%
if K.image_dim_ordering() == 'th':
	input_shape_img = (3, None, None)
	input_shape_features = (num_features, None, None)
else:
	input_shape_img = (None, None, 3)
	input_shape_features = (None, None, num_features)


img_input = Input(shape=input_shape_img)
roi_input = Input(shape=(C.num_rois, 4))
feature_map_input = Input(shape=input_shape_features)

# define the base network (resnet here, can be VGG, Inception, etc)
shared_layers = nn.nn_base(img_input, trainable=True)

# define the RPN, built on the base layers
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
rpn_layers = nn.rpn(shared_layers, num_anchors)

classifier = nn.classifier(feature_map_input, roi_input, C.num_rois, nb_classes=len(class_mapping), trainable=True)

model_rpn = Model(img_input, rpn_layers)
#model_classifier_only = Model([feature_map_input, roi_input], classifier)
model_classifier = Model([feature_map_input, roi_input], classifier)

# model loading
print('Loading weights from {}'.format(C.model_path))
model_rpn.load_weights(C.model_path, by_name=True)
model_classifier.load_weights(C.model_path, by_name=True)


model_rpn.compile(optimizer='sgd', loss='mse')
model_classifier.compile(optimizer='sgd', loss='mse')

all_imgs = []

classes = {}

bbox_threshold = 0.5

visualise = True
# Out:
# WARNING:tensorflow:From /N/u/imtiazahmad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /N/u/imtiazahmad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /N/u/imtiazahmad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /N/u/imtiazahmad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /N/u/imtiazahmad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /N/u/imtiazahmad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /N/u/imtiazahmad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /N/u/imtiazahmad/frcnn-from-scratch-with-keras/keras_frcnn/RoiPoolingConv.py:105: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /N/u/imtiazahmad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /N/u/imtiazahmad/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Loading weights from /N/u/imtiazahmad/frcnn-from-scratch-with-keras/models/resnet50/voc.hdf5
# WARNING:tensorflow:From /N/u/imtiazahmad/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# # set up dataset

# %%
# define pascal
DEVKIT_PATH = "/N/u/imtiazahmad/VOC/test/VOCdevkit/"
SET = "trainval"
pascal = pascal_voc_util(DEVKIT_PATH)

# define dataloader
all_imgs, classes_count, _ = get_data(DEVKIT_PATH)
val_imgs = [s for s in all_imgs if s['imageset'] == SET]
if len(val_imgs) == 0:
    print(SET, " images not found. using trainval images for testing.")
    val_imgs = [s for s in all_imgs if s['imageset'] == 'trainval'] # for test purpose
    
print('Num val samples {}'.format(len(val_imgs)))
data_gen_val = data_generators.get_anchor_gt(val_imgs, classes_count, C, nn.get_img_output_length,K.image_dim_ordering(), mode='val')

img_pathes = [x["filepath"] for x in val_imgs]

# define detections
all_boxes = [[[] for _ in range(len(val_imgs))]
               for _ in range(21)]
empty_array = np.transpose(np.array([[],[],[],[],[]]), (1,0))
# Out:
# data path: ['/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007']
# Parsing annotation files
# Num val samples 187

# %%
all_imgs
# Out:
# [{'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/frame511.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 6,
#     'x2': 813,
#     'y1': 261,
#     'y2': 579,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2058.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 554,
#     'x2': 1049,
#     'y1': 335,
#     'y2': 489,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2830.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 206,
#     'x2': 819,
#     'y1': 274,
#     'y2': 434,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_109.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 5,
#     'x2': 380,
#     'y1': 216,
#     'y2': 403,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 67,
#     'x2': 1268,
#     'y1': 375,
#     'y2': 720,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 469,
#     'x2': 525,
#     'y1': 172,
#     'y2': 195,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 545,
#     'x2': 597,
#     'y1': 173,
#     'y2': 195,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 625,
#     'x2': 684,
#     'y1': 172,
#     'y2': 196,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1121.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 526,
#     'x2': 647,
#     'y1': 337,
#     'y2': 426,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 253,
#     'x2': 374,
#     'y1': 185,
#     'y2': 274,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2044.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 832,
#     'x2': 926,
#     'y1': 605,
#     'y2': 680,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 705,
#     'x2': 798,
#     'y1': 603,
#     'y2': 672,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 699,
#     'x2': 785,
#     'y1': 550,
#     'y2': 608,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 700,
#     'x2': 786,
#     'y1': 491,
#     'y2': 543,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 733,
#     'x2': 817,
#     'y1': 442,
#     'y2': 492,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 761,
#     'x2': 834,
#     'y1': 364,
#     'y2': 417,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 783,
#     'x2': 839,
#     'y1': 284,
#     'y2': 323,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 860,
#     'x2': 917,
#     'y1': 277,
#     'y2': 320,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 798,
#     'x2': 849,
#     'y1': 212,
#     'y2': 251,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 821,
#     'x2': 870,
#     'y1': 186,
#     'y2': 215,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 810,
#     'x2': 860,
#     'y1': 170,
#     'y2': 203,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 827,
#     'x2': 867,
#     'y1': 147,
#     'y2': 172,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 837,
#     'x2': 873,
#     'y1': 131,
#     'y2': 152,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 881,
#     'x2': 917,
#     'y1': 126,
#     'y2': 155,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_932.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 1,
#     'x2': 336,
#     'y1': 201,
#     'y2': 451,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 2,
#     'x2': 1280,
#     'y1': 301,
#     'y2': 714,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1933.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 342,
#     'x2': 397,
#     'y1': 447,
#     'y2': 477,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 441,
#     'x2': 490,
#     'y1': 438,
#     'y2': 476,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 498,
#     'x2': 551,
#     'y1': 435,
#     'y2': 467,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 598,
#     'x2': 667,
#     'y1': 437,
#     'y2': 463,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 754,
#     'x2': 822,
#     'y1': 431,
#     'y2': 460,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_3375.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 503,
#     'x2': 854,
#     'y1': 266,
#     'y2': 388,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2755.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 215,
#     'x2': 292,
#     'y1': 302,
#     'y2': 347,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 289,
#     'x2': 310,
#     'y1': 300,
#     'y2': 318,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1993.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 329,
#     'x2': 376,
#     'y1': 669,
#     'y2': 698,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 450,
#     'x2': 493,
#     'y1': 618,
#     'y2': 636,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 511,
#     'x2': 550,
#     'y1': 581,
#     'y2': 603,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 689,
#     'x2': 727,
#     'y1': 470,
#     'y2': 496,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 765,
#     'x2': 807,
#     'y1': 411,
#     'y2': 428,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 836,
#     'x2': 877,
#     'y1': 355,
#     'y2': 380,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 875,
#     'x2': 910,
#     'y1': 313,
#     'y2': 339,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 925,
#     'x2': 959,
#     'y1': 290,
#     'y2': 315,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1047,
#     'x2': 1071,
#     'y1': 153,
#     'y2': 176,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1184,
#     'x2': 1208,
#     'y1': 26,
#     'y2': 47,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1600.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 775,
#     'x2': 1068,
#     'y1': 258,
#     'y2': 397,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1464.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 46,
#     'x2': 1200,
#     'y1': 369,
#     'y2': 720,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 616,
#     'x2': 701,
#     'y1': 250,
#     'y2': 292,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 681,
#     'x2': 719,
#     'y1': 239,
#     'y2': 261,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_190.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 333,
#     'x2': 1023,
#     'y1': 333,
#     'y2': 707,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 440,
#     'x2': 1078,
#     'y1': 180,
#     'y2': 508,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1053,
#     'x2': 1280,
#     'y1': 57,
#     'y2': 304,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1770.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 6,
#     'x2': 1276,
#     'y1': 17,
#     'y2': 720,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_3259.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 431,
#     'x2': 476,
#     'y1': 287,
#     'y2': 317,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 467,
#     'x2': 515,
#     'y1': 318,
#     'y2': 355,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 460,
#     'x2': 518,
#     'y1': 371,
#     'y2': 412,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 550,
#     'x2': 588,
#     'y1': 231,
#     'y2': 263,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 539,
#     'x2': 602,
#     'y1': 403,
#     'y2': 444,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 514,
#     'x2': 547,
#     'y1': 223,
#     'y2': 245,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 695,
#     'x2': 806,
#     'y1': 586,
#     'y2': 643,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 546,
#     'x2': 628,
#     'y1': 483,
#     'y2': 524,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2600.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 354,
#     'x2': 1087,
#     'y1': 151,
#     'y2': 496,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/ff305.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 587,
#     'x2': 740,
#     'y1': 586,
#     'y2': 703,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 660,
#     'x2': 723,
#     'y1': 430,
#     'y2': 480,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 606,
#     'x2': 660,
#     'y1': 435,
#     'y2': 477,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 555,
#     'x2': 623,
#     'y1': 446,
#     'y2': 496,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 586,
#     'x2': 638,
#     'y1': 406,
#     'y2': 436,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 516,
#     'x2': 568,
#     'y1': 404,
#     'y2': 429,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2696.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 1138,
#     'x2': 1200,
#     'y1': 318,
#     'y2': 350,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1228,
#     'x2': 1259,
#     'y1': 313,
#     'y2': 332,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2682.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 487,
#     'x2': 538,
#     'y1': 332,
#     'y2': 367,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 415,
#     'x2': 465,
#     'y1': 321,
#     'y2': 353,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 453,
#     'x2': 481,
#     'y1': 239,
#     'y2': 259,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 490,
#     'x2': 516,
#     'y1': 219,
#     'y2': 237,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1628.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 393,
#     'x2': 492,
#     'y1': 538,
#     'y2': 599,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 487,
#     'x2': 557,
#     'y1': 445,
#     'y2': 489,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 588,
#     'x2': 634,
#     'y1': 358,
#     'y2': 387,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 613,
#     'x2': 650,
#     'y1': 340,
#     'y2': 366,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 623,
#     'x2': 661,
#     'y1': 328,
#     'y2': 348,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 632,
#     'x2': 662,
#     'y1': 283,
#     'y2': 304,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 634,
#     'x2': 652,
#     'y1': 266,
#     'y2': 280,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 621,
#     'x2': 641,
#     'y1': 256,
#     'y2': 273,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 606,
#     'x2': 622,
#     'y1': 243,
#     'y2': 260,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 647,
#     'x2': 660,
#     'y1': 236,
#     'y2': 252,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1519.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 651,
#     'x2': 727,
#     'y1': 378,
#     'y2': 435,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_3245.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 451,
#     'x2': 523,
#     'y1': 472,
#     'y2': 526,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 486,
#     'x2': 551,
#     'y1': 417,
#     'y2': 459,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 572,
#     'x2': 621,
#     'y1': 324,
#     'y2': 355,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 605,
#     'x2': 648,
#     'y1': 295,
#     'y2': 320,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 668,
#     'x2': 700,
#     'y1': 256,
#     'y2': 275,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 698,
#     'x2': 728,
#     'y1': 224,
#     'y2': 245,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_993.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 288,
#     'x2': 395,
#     'y1': 318,
#     'y2': 380,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1034,
#     'x2': 1108,
#     'y1': 260,
#     'y2': 281,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2331.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 223,
#     'x2': 1026,
#     'y1': 153,
#     'y2': 604,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_450.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 454,
#     'x2': 507,
#     'y1': 350,
#     'y2': 381,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 396,
#     'x2': 439,
#     'y1': 345,
#     'y2': 369,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 747,
#     'x2': 994,
#     'y1': 402,
#     'y2': 510,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 513,
#     'x2': 1013,
#     'y1': 467,
#     'y2': 710,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_928.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 10,
#     'x2': 1277,
#     'y1': 285,
#     'y2': 716,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 497,
#     'x2': 653,
#     'y1': 206,
#     'y2': 282,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1852.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 32,
#     'x2': 1227,
#     'y1': 281,
#     'y2': 720,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2233.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 1263,
#     'x2': 1280,
#     'y1': 124,
#     'y2': 144,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1232,
#     'x2': 1271,
#     'y1': 144,
#     'y2': 166,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1171,
#     'x2': 1220,
#     'y1': 176,
#     'y2': 204,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1141,
#     'x2': 1192,
#     'y1': 196,
#     'y2': 217,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1108,
#     'x2': 1161,
#     'y1': 210,
#     'y2': 243,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1037,
#     'x2': 1099,
#     'y1': 237,
#     'y2': 272,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 952,
#     'x2': 1017,
#     'y1': 232,
#     'y2': 267,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 908,
#     'x2': 988,
#     'y1': 281,
#     'y2': 324,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 769,
#     'x2': 860,
#     'y1': 348,
#     'y2': 395,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 723,
#     'x2': 813,
#     'y1': 330,
#     'y2': 375,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 550,
#     'x2': 669,
#     'y1': 409,
#     'y2': 480,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 439,
#     'x2': 553,
#     'y1': 397,
#     'y2': 463,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1115.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 930,
#     'x2': 1093,
#     'y1': 218,
#     'y2': 325,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 267,
#     'x2': 519,
#     'y1': 430,
#     'y2': 586,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1234,
#     'x2': 1280,
#     'y1': 111,
#     'y2': 180,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_3395.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 449,
#     'x2': 534,
#     'y1': 310,
#     'y2': 361,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 386,
#     'x2': 415,
#     'y1': 256,
#     'y2': 273,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2380.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 1,
#     'x2': 127,
#     'y1': 420,
#     'y2': 525,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 432,
#     'x2': 566,
#     'y1': 351,
#     'y2': 426,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 531,
#     'x2': 657,
#     'y1': 348,
#     'y2': 408,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 521,
#     'x2': 630,
#     'y1': 311,
#     'y2': 368,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 625,
#     'x2': 715,
#     'y1': 303,
#     'y2': 348,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 619,
#     'x2': 721,
#     'y1': 280,
#     'y2': 322,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 632,
#     'x2': 722,
#     'y1': 261,
#     'y2': 296,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 631,
#     'x2': 709,
#     'y1': 240,
#     'y2': 269,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 573,
#     'x2': 632,
#     'y1': 233,
#     'y2': 268,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 508,
#     'x2': 573,
#     'y1': 222,
#     'y2': 259,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 442,
#     'x2': 501,
#     'y1': 208,
#     'y2': 239,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 483,
#     'x2': 540,
#     'y1': 197,
#     'y2': 224,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 511,
#     'x2': 594,
#     'y1': 189,
#     'y2': 216,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 689,
#     'x2': 737,
#     'y1': 192,
#     'y2': 226,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 900,
#     'x2': 974,
#     'y1': 186,
#     'y2': 221,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1116,
#     'x2': 1197,
#     'y1': 175,
#     'y2': 217,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_3299.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 446,
#     'x2': 799,
#     'y1': 402,
#     'y2': 506,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1371.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 276,
#     'x2': 1025,
#     'y1': 161,
#     'y2': 525,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_374.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 994,
#     'x2': 1026,
#     'y1': 535,
#     'y2': 558,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 930,
#     'x2': 962,
#     'y1': 447,
#     'y2': 471,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 915,
#     'x2': 947,
#     'y1': 390,
#     'y2': 414,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 845,
#     'x2': 877,
#     'y1': 299,
#     'y2': 323,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 813,
#     'x2': 840,
#     'y1': 279,
#     'y2': 303,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 773,
#     'x2': 805,
#     'y1': 241,
#     'y2': 265,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 734,
#     'x2': 766,
#     'y1': 213,
#     'y2': 237,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 665,
#     'x2': 697,
#     'y1': 186,
#     'y2': 210,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 617,
#     'x2': 649,
#     'y1': 155,
#     'y2': 179,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 500,
#     'x2': 532,
#     'y1': 118,
#     'y2': 142,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 520,
#     'x2': 552,
#     'y1': 120,
#     'y2': 144,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1010,
#     'x2': 1042,
#     'y1': 572,
#     'y2': 595,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1056,
#     'x2': 1088,
#     'y1': 697,
#     'y2': 720,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2261.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 1106,
#     'x2': 1219,
#     'y1': 295,
#     'y2': 358,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 695,
#     'x2': 905,
#     'y1': 421,
#     'y2': 516,
#     'difficult': 1},
#    {'class': 'car', 'x1': 1, 'x2': 190, 'y1': 642, 'y2': 720, 'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_444.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 375,
#     'x2': 590,
#     'y1': 595,
#     'y2': 698,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 732,
#     'x2': 861,
#     'y1': 423,
#     'y2': 485,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 925,
#     'x2': 1011,
#     'y1': 326,
#     'y2': 376,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 979,
#     'x2': 1052,
#     'y1': 257,
#     'y2': 303,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1011,
#     'x2': 1068,
#     'y1': 200,
#     'y2': 237,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1111,
#     'x2': 1166,
#     'y1': 218,
#     'y2': 258,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2747.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 509,
#     'x2': 593,
#     'y1': 318,
#     'y2': 364,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 793,
#     'x2': 864,
#     'y1': 325,
#     'y2': 362,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1194,
#     'x2': 1261,
#     'y1': 324,
#     'y2': 356,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_584.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 619,
#     'x2': 1101,
#     'y1': 276,
#     'y2': 505,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_3351.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 1,
#     'x2': 132,
#     'y1': 337,
#     'y2': 428,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 102,
#     'x2': 175,
#     'y1': 316,
#     'y2': 363,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 251,
#     'x2': 305,
#     'y1': 319,
#     'y2': 352,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 461,
#     'x2': 503,
#     'y1': 319,
#     'y2': 348,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 723,
#     'x2': 765,
#     'y1': 317,
#     'y2': 341,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1000,
#     'x2': 1039,
#     'y1': 317,
#     'y2': 336,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1352.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 382,
#     'x2': 956,
#     'y1': 311,
#     'y2': 482,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1157.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 293,
#     'x2': 1046,
#     'y1': 142,
#     'y2': 534,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2289.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 356,
#     'x2': 437,
#     'y1': 475,
#     'y2': 538,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 382,
#     'x2': 443,
#     'y1': 408,
#     'y2': 464,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 470,
#     'x2': 521,
#     'y1': 346,
#     'y2': 390,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 531,
#     'x2': 583,
#     'y1': 318,
#     'y2': 357,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 637,
#     'x2': 691,
#     'y1': 286,
#     'y2': 320,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 778,
#     'x2': 831,
#     'y1': 257,
#     'y2': 289,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 954,
#     'x2': 1008,
#     'y1': 229,
#     'y2': 259,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1055,
#     'x2': 1105,
#     'y1': 208,
#     'y2': 240,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1179,
#     'x2': 1233,
#     'y1': 182,
#     'y2': 215,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1727.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 826,
#     'x2': 882,
#     'y1': 308,
#     'y2': 353,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 930,
#     'x2': 996,
#     'y1': 386,
#     'y2': 441,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1671.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 625,
#     'x2': 781,
#     'y1': 435,
#     'y2': 523,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 696,
#     'x2': 813,
#     'y1': 302,
#     'y2': 381,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 671,
#     'x2': 772,
#     'y1': 231,
#     'y2': 292,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 621,
#     'x2': 694,
#     'y1': 107,
#     'y2': 148,
#     'difficult': 1},
#    {'class': 'car', 'x1': 687, 'x2': 758, 'y1': 4, 'y2': 38, 'difficult': 1},
#    {'class': 'car', 'x1': 956, 'x2': 1031, 'y1': 1, 'y2': 25, 'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1997.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 541,
#     'x2': 569,
#     'y1': 647,
#     'y2': 679,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 592,
#     'x2': 616,
#     'y1': 597,
#     'y2': 629,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 677,
#     'x2': 703,
#     'y1': 467,
#     'y2': 492,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 739,
#     'x2': 769,
#     'y1': 466,
#     'y2': 490,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 745,
#     'x2': 770,
#     'y1': 371,
#     'y2': 389,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 779,
#     'x2': 809,
#     'y1': 320,
#     'y2': 343,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 805,
#     'x2': 829,
#     'y1': 263,
#     'y2': 283,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 848,
#     'x2': 873,
#     'y1': 230,
#     'y2': 248,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 917,
#     'x2': 943,
#     'y1': 250,
#     'y2': 269,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 948,
#     'x2': 970,
#     'y1': 96,
#     'y2': 113,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1971.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 859,
#     'x2': 918,
#     'y1': 462,
#     'y2': 493,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 860,
#     'x2': 932,
#     'y1': 543,
#     'y2': 590,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 823,
#     'x2': 905,
#     'y1': 597,
#     'y2': 635,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 782,
#     'x2': 870,
#     'y1': 651,
#     'y2': 698,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/frame966.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 671,
#     'x2': 826,
#     'y1': 371,
#     'y2': 450,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 693,
#     'x2': 780,
#     'y1': 342,
#     'y2': 384,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 818,
#     'x2': 905,
#     'y1': 350,
#     'y2': 396,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 962,
#     'x2': 992,
#     'y1': 334,
#     'y2': 353,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1954.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 369,
#     'x2': 484,
#     'y1': 342,
#     'y2': 400,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 825,
#     'x2': 995,
#     'y1': 470,
#     'y2': 548,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 867,
#     'x2': 1058,
#     'y1': 535,
#     'y2': 613,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1988.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 43,
#     'x2': 101,
#     'y1': 479,
#     'y2': 509,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 151,
#     'x2': 208,
#     'y1': 480,
#     'y2': 503,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 413,
#     'x2': 465,
#     'y1': 460,
#     'y2': 490,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 520,
#     'x2': 573,
#     'y1': 451,
#     'y2': 471,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 619,
#     'x2': 674,
#     'y1': 435,
#     'y2': 458,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 712,
#     'x2': 771,
#     'y1': 422,
#     'y2': 445,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 788,
#     'x2': 842,
#     'y1': 407,
#     'y2': 432,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1077,
#     'x2': 1123,
#     'y1': 341,
#     'y2': 367,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/frame462.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 363,
#     'x2': 1251,
#     'y1': 295,
#     'y2': 526,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1479.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 73,
#     'x2': 1198,
#     'y1': 359,
#     'y2': 720,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 720,
#     'x2': 888,
#     'y1': 237,
#     'y2': 338,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 633,
#     'x2': 661,
#     'y1': 239,
#     'y2': 261,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 558,
#     'x2': 651,
#     'y1': 233,
#     'y2': 303,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1866.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 229,
#     'x2': 290,
#     'y1': 258,
#     'y2': 292,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 406,
#     'x2': 474,
#     'y1': 295,
#     'y2': 324,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 508,
#     'x2': 579,
#     'y1': 333,
#     'y2': 366,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 676,
#     'x2': 756,
#     'y1': 372,
#     'y2': 413,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 674,
#     'x2': 748,
#     'y1': 420,
#     'y2': 451,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 880,
#     'x2': 972,
#     'y1': 455,
#     'y2': 497,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 858,
#     'x2': 949,
#     'y1': 485,
#     'y2': 536,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 820,
#     'x2': 921,
#     'y1': 671,
#     'y2': 716,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/ff157.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 463,
#     'x2': 511,
#     'y1': 417,
#     'y2': 452,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 415,
#     'x2': 458,
#     'y1': 401,
#     'y2': 447,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 360,
#     'x2': 410,
#     'y1': 396,
#     'y2': 441,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 558,
#     'x2': 595,
#     'y1': 360,
#     'y2': 397,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 500,
#     'x2': 542,
#     'y1': 359,
#     'y2': 391,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 454,
#     'x2': 496,
#     'y1': 347,
#     'y2': 394,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 845,
#     'x2': 881,
#     'y1': 294,
#     'y2': 320,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 815,
#     'x2': 840,
#     'y1': 285,
#     'y2': 322,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 768,
#     'x2': 801,
#     'y1': 286,
#     'y2': 322,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1018,
#     'x2': 1049,
#     'y1': 257,
#     'y2': 285,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 989,
#     'x2': 1011,
#     'y1': 254,
#     'y2': 288,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 932,
#     'x2': 971,
#     'y1': 264,
#     'y2': 285,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 666,
#     'x2': 713,
#     'y1': 338,
#     'y2': 357,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 632,
#     'x2': 663,
#     'y1': 323,
#     'y2': 362,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 592,
#     'x2': 623,
#     'y1': 310,
#     'y2': 352,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/frame804.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 1,
#     'x2': 415,
#     'y1': 267,
#     'y2': 560,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 412,
#     'x2': 1276,
#     'y1': 290,
#     'y2': 720,
#     'difficult': 1},
#    {'class': 'car', 'x1': 2, 'x2': 253, 'y1': 184, 'y2': 271, 'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_418.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 3,
#     'x2': 778,
#     'y1': 229,
#     'y2': 557,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/ff55.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 647,
#     'x2': 732,
#     'y1': 273,
#     'y2': 309,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 579,
#     'x2': 665,
#     'y1': 265,
#     'y2': 313,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 512,
#     'x2': 596,
#     'y1': 264,
#     'y2': 306,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_438.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 658,
#     'x2': 727,
#     'y1': 481,
#     'y2': 516,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 652,
#     'x2': 702,
#     'y1': 455,
#     'y2': 481,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 667,
#     'x2': 705,
#     'y1': 390,
#     'y2': 410,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 515,
#     'x2': 549,
#     'y1': 412,
#     'y2': 435,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 566,
#     'x2': 592,
#     'y1': 383,
#     'y2': 395,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 576,
#     'x2': 610,
#     'y1': 419,
#     'y2': 437,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 510,
#     'x2': 533,
#     'y1': 388,
#     'y2': 400,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_135.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 368,
#     'x2': 486,
#     'y1': 188,
#     'y2': 233,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 514,
#     'x2': 613,
#     'y1': 179,
#     'y2': 227,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 650,
#     'x2': 779,
#     'y1': 187,
#     'y2': 255,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 105,
#     'x2': 1209,
#     'y1': 368,
#     'y2': 720,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_81.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 8,
#     'x2': 1199,
#     'y1': 325,
#     'y2': 720,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 869,
#     'x2': 1219,
#     'y1': 148,
#     'y2': 328,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 562,
#     'x2': 589,
#     'y1': 131,
#     'y2': 144,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 605,
#     'x2': 626,
#     'y1': 128,
#     'y2': 147,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 642,
#     'x2': 660,
#     'y1': 133,
#     'y2': 144,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2321.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 591,
#     'x2': 692,
#     'y1': 416,
#     'y2': 470,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 676,
#     'x2': 766,
#     'y1': 370,
#     'y2': 433,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 707,
#     'x2': 791,
#     'y1': 286,
#     'y2': 345,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 845,
#     'x2': 912,
#     'y1': 208,
#     'y2': 241,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 859,
#     'x2': 926,
#     'y1': 181,
#     'y2': 219,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 860,
#     'x2': 923,
#     'y1': 131,
#     'y2': 170,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 893,
#     'x2': 953,
#     'y1': 102,
#     'y2': 136,
#     'difficult': 1},
#    {'class': 'car', 'x1': 932, 'x2': 981, 'y1': 1, 'y2': 22, 'difficult': 1},
#    {'class': 'car', 'x1': 929, 'x2': 980, 'y1': 18, 'y2': 41, 'difficult': 1},
#    {'class': 'car', 'x1': 913, 'x2': 968, 'y1': 32, 'y2': 58, 'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2792.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 52,
#     'x2': 1208,
#     'y1': 360,
#     'y2': 719,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 556,
#     'x2': 583,
#     'y1': 147,
#     'y2': 166,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_3231.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 90,
#     'x2': 468,
#     'y1': 347,
#     'y2': 521,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 136,
#     'x2': 272,
#     'y1': 248,
#     'y2': 329,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 327,
#     'x2': 426,
#     'y1': 259,
#     'y2': 321,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 396,
#     'x2': 487,
#     'y1': 259,
#     'y2': 303,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 553,
#     'x2': 637,
#     'y1': 263,
#     'y2': 305,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 683,
#     'x2': 774,
#     'y1': 257,
#     'y2': 298,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 770,
#     'x2': 840,
#     'y1': 264,
#     'y2': 302,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 935,
#     'x2': 1007,
#     'y1': 263,
#     'y2': 296,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1040,
#     'x2': 1108,
#     'y1': 248,
#     'y2': 285,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1228,
#     'x2': 1280,
#     'y1': 253,
#     'y2': 283,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1804.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 3,
#     'x2': 68,
#     'y1': 392,
#     'y2': 436,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 296,
#     'x2': 382,
#     'y1': 372,
#     'y2': 411,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 593,
#     'x2': 679,
#     'y1': 367,
#     'y2': 398,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 768,
#     'x2': 847,
#     'y1': 347,
#     'y2': 375,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 999,
#     'x2': 1088,
#     'y1': 333,
#     'y2': 365,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1112,
#     'x2': 1197,
#     'y1': 346,
#     'y2': 371,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1438.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 352,
#     'x2': 1009,
#     'y1': 343,
#     'y2': 550,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2452.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 95,
#     'x2': 227,
#     'y1': 390,
#     'y2': 449,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 357,
#     'x2': 483,
#     'y1': 362,
#     'y2': 412,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1117,
#     'x2': 1249,
#     'y1': 321,
#     'y2': 382,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 766,
#     'x2': 877,
#     'y1': 327,
#     'y2': 381,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 700,
#     'x2': 823,
#     'y1': 364,
#     'y2': 407,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2762.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 483,
#     'x2': 544,
#     'y1': 349,
#     'y2': 380,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 417,
#     'x2': 458,
#     'y1': 343,
#     'y2': 365,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2069.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 789,
#     'x2': 858,
#     'y1': 273,
#     'y2': 315,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 719,
#     'x2': 789,
#     'y1': 246,
#     'y2': 272,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 488,
#     'x2': 565,
#     'y1': 219,
#     'y2': 259,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 446,
#     'x2': 485,
#     'y1': 201,
#     'y2': 242,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_335.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 7,
#     'x2': 1256,
#     'y1': 310,
#     'y2': 718,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 542,
#     'x2': 608,
#     'y1': 120,
#     'y2': 165,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/frame579.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 354,
#     'x2': 408,
#     'y1': 395,
#     'y2': 432,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 414,
#     'x2': 456,
#     'y1': 409,
#     'y2': 438,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 461,
#     'x2': 508,
#     'y1': 417,
#     'y2': 452,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 471,
#     'x2': 522,
#     'y1': 356,
#     'y2': 388,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 847,
#     'x2': 887,
#     'y1': 292,
#     'y2': 320,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 525,
#     'x2': 575,
#     'y1': 363,
#     'y2': 399,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 572,
#     'x2': 624,
#     'y1': 369,
#     'y2': 398,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 629,
#     'x2': 662,
#     'y1': 328,
#     'y2': 345,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 666,
#     'x2': 698,
#     'y1': 335,
#     'y2': 358,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 702,
#     'x2': 744,
#     'y1': 339,
#     'y2': 369,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 799,
#     'x2': 839,
#     'y1': 298,
#     'y2': 322,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 888,
#     'x2': 920,
#     'y1': 297,
#     'y2': 321,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 983,
#     'x2': 1011,
#     'y1': 268,
#     'y2': 288,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1023,
#     'x2': 1054,
#     'y1': 261,
#     'y2': 289,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1056,
#     'x2': 1089,
#     'y1': 266,
#     'y2': 287,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2247.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 251,
#     'x2': 291,
#     'y1': 298,
#     'y2': 323,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 437,
#     'x2': 463,
#     'y1': 295,
#     'y2': 311,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_704.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 436,
#     'x2': 735,
#     'y1': 266,
#     'y2': 462,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_3329.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 688,
#     'x2': 919,
#     'y1': 469,
#     'y2': 543,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1657.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 158,
#     'x2': 193,
#     'y1': 509,
#     'y2': 543,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 354,
#     'x2': 377,
#     'y1': 409,
#     'y2': 426,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1587.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 370,
#     'x2': 919,
#     'y1': 140,
#     'y2': 391,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2599.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 934,
#     'x2': 1280,
#     'y1': 22,
#     'y2': 365,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 272,
#     'x2': 1051,
#     'y1': 175,
#     'y2': 563,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1884.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 462,
#     'x2': 689,
#     'y1': 407,
#     'y2': 495,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 862,
#     'x2': 1123,
#     'y1': 369,
#     'y2': 457,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 742,
#     'x2': 1053,
#     'y1': 360,
#     'y2': 441,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1835.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 10,
#     'x2': 1223,
#     'y1': 369,
#     'y2': 720,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 646,
#     'x2': 708,
#     'y1': 316,
#     'y2': 346,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 563,
#     'x2': 614,
#     'y1': 313,
#     'y2': 335,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/ff105.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 598,
#     'x2': 680,
#     'y1': 326,
#     'y2': 365,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 692,
#     'x2': 792,
#     'y1': 325,
#     'y2': 371,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 802,
#     'x2': 892,
#     'y1': 325,
#     'y2': 364,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2500.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 883,
#     'x2': 1094,
#     'y1': 192,
#     'y2': 309,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 507,
#     'x2': 723,
#     'y1': 320,
#     'y2': 442,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 401,
#     'x2': 646,
#     'y1': 368,
#     'y2': 500,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 91,
#     'x2': 346,
#     'y1': 432,
#     'y2': 592,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2620.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 322,
#     'x2': 400,
#     'y1': 505,
#     'y2': 536,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 551,
#     'x2': 608,
#     'y1': 431,
#     'y2': 453,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 719,
#     'x2': 766,
#     'y1': 369,
#     'y2': 388,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 772,
#     'x2': 805,
#     'y1': 345,
#     'y2': 366,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 825,
# ...
#     'y2': 343,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 554,
#     'x2': 582,
#     'y1': 315,
#     'y2': 333,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 529,
#     'x2': 550,
#     'y1': 309,
#     'y2': 329,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_3365.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 698,
#     'x2': 989,
#     'y1': 371,
#     'y2': 508,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2662.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 197,
#     'x2': 729,
#     'y1': 185,
#     'y2': 450,
#     'difficult': 1},
#    {'class': 'car', 'x1': 7, 'x2': 932, 'y1': 372, 'y2': 720, 'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_371.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 1035,
#     'x2': 1067,
#     'y1': 573,
#     'y2': 598,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 895,
#     'x2': 927,
#     'y1': 435,
#     'y2': 461,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 899,
#     'x2': 931,
#     'y1': 411,
#     'y2': 437,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 791,
#     'x2': 823,
#     'y1': 320,
#     'y2': 346,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 745,
#     'x2': 777,
#     'y1': 297,
#     'y2': 322,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 712,
#     'x2': 744,
#     'y1': 253,
#     'y2': 279,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 643,
#     'x2': 675,
#     'y1': 207,
#     'y2': 233,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 600,
#     'x2': 632,
#     'y1': 166,
#     'y2': 192,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 565,
#     'x2': 597,
#     'y1': 139,
#     'y2': 165,
#     'difficult': 1},
#    {'class': 'car', 'x1': 479, 'x2': 511, 'y1': 99, 'y2': 124, 'difficult': 1},
#    {'class': 'car', 'x1': 502, 'x2': 534, 'y1': 98, 'y2': 124, 'difficult': 1},
#    {'class': 'car',
#     'x1': 1073,
#     'x2': 1105,
#     'y1': 613,
#     'y2': 638,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2533.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 482,
#     'x2': 872,
#     'y1': 242,
#     'y2': 441,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 902,
#     'x2': 1212,
#     'y1': 228,
#     'y2': 432,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2072.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 188,
#     'x2': 309,
#     'y1': 257,
#     'y2': 319,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1030,
#     'x2': 1091,
#     'y1': 324,
#     'y2': 370,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2030.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 859,
#     'x2': 913,
#     'y1': 292,
#     'y2': 326,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 859,
#     'x2': 882,
#     'y1': 81,
#     'y2': 102,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1401.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 292,
#     'x2': 986,
#     'y1': 235,
#     'y2': 487,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/frame541.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 76,
#     'x2': 912,
#     'y1': 135,
#     'y2': 581,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/ff232.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 629,
#     'x2': 940,
#     'y1': 120,
#     'y2': 217,
#     'difficult': 1},
#    {'class': 'car', 'x1': 85, 'x2': 838, 'y1': 135, 'y2': 407, 'difficult': 1},
#    {'class': 'car',
#     'x1': 269,
#     'x2': 1280,
#     'y1': 313,
#     'y2': 713,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1614.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 718,
#     'x2': 1162,
#     'y1': 290,
#     'y2': 429,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_75.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 2,
#     'x2': 1219,
#     'y1': 332,
#     'y2': 720,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 881,
#     'x2': 1280,
#     'y1': 193,
#     'y2': 446,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 518,
#     'x2': 543,
#     'y1': 129,
#     'y2': 148,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 556,
#     'x2': 583,
#     'y1': 134,
#     'y2': 149,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 602,
#     'x2': 634,
#     'y1': 131,
#     'y2': 151,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2679.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 81,
#     'x2': 253,
#     'y1': 468,
#     'y2': 565,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 212,
#     'x2': 351,
#     'y1': 447,
#     'y2': 540,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 437,
#     'x2': 577,
#     'y1': 402,
#     'y2': 484,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 534,
#     'x2': 673,
#     'y1': 381,
#     'y2': 448,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 728,
#     'x2': 845,
#     'y1': 305,
#     'y2': 373,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 801,
#     'x2': 902,
#     'y1': 285,
#     'y2': 350,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 856,
#     'x2': 963,
#     'y1': 260,
#     'y2': 317,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 921,
#     'x2': 1030,
#     'y1': 244,
#     'y2': 298,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 966,
#     'x2': 1051,
#     'y1': 227,
#     'y2': 269,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1027,
#     'x2': 1102,
#     'y1': 213,
#     'y2': 268,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1091,
#     'x2': 1191,
#     'y1': 189,
#     'y2': 241,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_504.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 536,
#     'x2': 656,
#     'y1': 229,
#     'y2': 309,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 783,
#     'x2': 908,
#     'y1': 247,
#     'y2': 328,
#     'difficult': 1},
#    {'class': 'car', 'x1': 595, 'x2': 693, 'y1': 1, 'y2': 56, 'difficult': 1},
#    {'class': 'car',
#     'x1': 937,
#     'x2': 1152,
#     'y1': 547,
#     'y2': 679,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1103.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 871,
#     'x2': 898,
#     'y1': 283,
#     'y2': 305,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 676,
#     'x2': 703,
#     'y1': 283,
#     'y2': 305,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 554,
#     'x2': 581,
#     'y1': 285,
#     'y2': 307,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 462,
#     'x2': 489,
#     'y1': 284,
#     'y2': 306,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 380,
#     'x2': 407,
#     'y1': 283,
#     'y2': 305,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 339,
#     'x2': 366,
#     'y1': 285,
#     'y2': 307,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 298,
#     'x2': 339,
#     'y1': 285,
#     'y2': 309,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 310,
#     'x2': 355,
#     'y1': 299,
#     'y2': 328,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2301.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 396,
#     'x2': 576,
#     'y1': 616,
#     'y2': 720,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 461,
#     'x2': 615,
#     'y1': 527,
#     'y2': 623,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 648,
#     'x2': 791,
#     'y1': 422,
#     'y2': 504,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 812,
#     'x2': 926,
#     'y1': 346,
#     'y2': 422,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 611,
#     'x2': 721,
#     'y1': 339,
#     'y2': 408,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 623,
#     'x2': 726,
#     'y1': 267,
#     'y2': 343,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 790,
#     'x2': 893,
#     'y1': 201,
#     'y2': 261,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 865,
#     'x2': 937,
#     'y1': 142,
#     'y2': 187,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 834,
#     'x2': 906,
#     'y1': 119,
#     'y2': 156,
#     'difficult': 1},
#    {'class': 'car', 'x1': 847, 'x2': 914, 'y1': 97, 'y2': 124, 'difficult': 1},
#    {'class': 'car', 'x1': 829, 'x2': 897, 'y1': 43, 'y2': 72, 'difficult': 1},
#    {'class': 'car', 'x1': 788, 'x2': 849, 'y1': 11, 'y2': 46, 'difficult': 1},
#    {'class': 'car', 'x1': 733, 'x2': 785, 'y1': 2, 'y2': 37, 'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2824.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 431,
#     'x2': 568,
#     'y1': 483,
#     'y2': 566,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 639,
#     'x2': 747,
#     'y1': 285,
#     'y2': 351,
#     'difficult': 1},
#    {'class': 'car', 'x1': 889, 'x2': 963, 'y1': 4, 'y2': 32, 'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2743.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 418,
#     'x2': 479,
#     'y1': 619,
#     'y2': 656,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 483,
#     'x2': 538,
#     'y1': 529,
#     'y2': 565,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 568,
#     'x2': 614,
#     'y1': 442,
#     'y2': 472,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 620,
#     'x2': 662,
#     'y1': 410,
#     'y2': 438,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 681,
#     'x2': 715,
#     'y1': 355,
#     'y2': 380,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 716,
#     'x2': 744,
#     'y1': 302,
#     'y2': 322,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 742,
#     'x2': 765,
#     'y1': 275,
#     'y2': 289,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2627.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 48,
#     'x2': 1207,
#     'y1': 357,
#     'y2': 720,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 530,
#     'x2': 650,
#     'y1': 152,
#     'y2': 225,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2728.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 273,
#     'x2': 616,
#     'y1': 241,
#     'y2': 391,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 636,
#     'x2': 842,
#     'y1': 247,
#     'y2': 402,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 132,
#     'x2': 1280,
#     'y1': 399,
#     'y2': 718,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 786,
#     'x2': 859,
#     'y1': 253,
#     'y2': 290,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1919.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 567,
#     'x2': 725,
#     'y1': 312,
#     'y2': 418,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 667,
#     'x2': 813,
#     'y1': 186,
#     'y2': 263,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 742,
#     'x2': 880,
#     'y1': 112,
#     'y2': 199,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_389.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 676,
#     'x2': 711,
#     'y1': 209,
#     'y2': 230,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/frame831.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 1,
#     'x2': 760,
#     'y1': 157,
#     'y2': 515,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 321,
#     'x2': 657,
#     'y1': 143,
#     'y2': 227,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 764,
#     'x2': 1280,
#     'y1': 309,
#     'y2': 717,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2002.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 380,
#     'x2': 565,
#     'y1': 287,
#     'y2': 384,
#     'difficult': 1},
#    {'class': 'car', 'x1': 32, 'x2': 81, 'y1': 231, 'y2': 260, 'difficult': 1},
#    {'class': 'car', 'x1': 62, 'x2': 110, 'y1': 224, 'y2': 259, 'difficult': 1},
#    {'class': 'car',
#     'x1': 209,
#     'x2': 250,
#     'y1': 237,
#     'y2': 264,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 239,
#     'x2': 285,
#     'y1': 231,
#     'y2': 264,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 163,
#     'x2': 200,
#     'y1': 220,
#     'y2': 247,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 205,
#     'x2': 241,
#     'y1': 224,
#     'y2': 245,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 354,
#     'x2': 388,
#     'y1': 219,
#     'y2': 243,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 407,
#     'x2': 431,
#     'y1': 223,
#     'y2': 240,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1937.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 384,
#     'x2': 488,
#     'y1': 435,
#     'y2': 485,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 428,
#     'x2': 523,
#     'y1': 407,
#     'y2': 457,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 499,
#     'x2': 584,
#     'y1': 389,
#     'y2': 433,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 547,
#     'x2': 625,
#     'y1': 364,
#     'y2': 410,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 610,
#     'x2': 693,
#     'y1': 344,
#     'y2': 389,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 824,
#     'x2': 912,
#     'y1': 307,
#     'y2': 352,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 916,
#     'x2': 998,
#     'y1': 302,
#     'y2': 343,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 1162,
#     'x2': 1259,
#     'y1': 282,
#     'y2': 321,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2806.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 566,
#     'x2': 596,
#     'y1': 151,
#     'y2': 171,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 41,
#     'x2': 1215,
#     'y1': 356,
#     'y2': 715,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_3339.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 345,
#     'x2': 435,
#     'y1': 285,
#     'y2': 330,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 259,
#     'x2': 325,
#     'y1': 279,
#     'y2': 319,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 189,
#     'x2': 245,
#     'y1': 271,
#     'y2': 304,
#     'difficult': 1},
#    {'class': 'car',
#     'x1': 280,
#     'x2': 328,
#     'y1': 259,
#     'y2': 281,
#     'difficult': 1}],
#   'imageset': 'trainval'},
#  {'filepath': '/N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_2634.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'car',
#     'x1': 49,
#     'x2': 1215,
#     'y1': 351,
#     'y2': 720,
#     'difficult': 1},
#    {'class': 'car', 'x1': 5, 'x2': 322, 'y1': 197, 'y2': 411, 'difficult': 1}],
#   'imageset': 'trainval'}]

# %%
len(all_boxes[0])
# Out:
# 187

# %% [markdown]
# # infer data

# %%
image_index = sorted(img_pathes)
print(len(image_index))
tottime = 0
for idx, img_name in enumerate(image_index):
	if not img_name.lower().endswith(('.bmp', '.jpeg', '.jpg', '.png', '.tif', '.tiff')):
		continue
	print("inference image path:", img_name)
	st = time.time()
	filepath = img_name

	img = cv2.imread(filepath)
    #print(img)
	X, ratio = format_img(img, C)
	img_scaled = (np.transpose(X[0,:,:,:],(1,2,0)) + 127.5).astype('uint8')

	if K.image_dim_ordering() == 'tf':
		X = np.transpose(X, (0, 2, 3, 1))

	# get the feature maps and output from the RPN
	[Y1, Y2, F] = model_rpn.predict(X)
	
    # infer roi
	R = roi_helpers.rpn_to_roi(Y1, Y2, C, K.image_dim_ordering(), overlap_thresh=0.5)
    # get bbox
#	all_dets, bboxes, probs = get_bbox(R, C, model_classifier, class_mapping, F, ratio, bbox_threshold=0.5)
    # convert from (x1,y1,x2,y2) to (x,y,w,h)
	R[:, 2] -= R[:, 0]
	R[:, 3] -= R[:, 1]

	# apply the spatial pyramid pooling to the proposed regions
	bboxes = {}
	probs = {}

	for jk in range(R.shape[0]//C.num_rois + 1):
		ROIs = np.expand_dims(R[C.num_rois*jk:C.num_rois*(jk+1), :], axis=0)
		if ROIs.shape[1] == 0:
			break

		if jk == R.shape[0]//C.num_rois:
			#pad R
			curr_shape = ROIs.shape
			target_shape = (curr_shape[0],C.num_rois,curr_shape[2])
			ROIs_padded = np.zeros(target_shape).astype(ROIs.dtype)
			ROIs_padded[:, :curr_shape[1], :] = ROIs
			ROIs_padded[0, curr_shape[1]:, :] = ROIs[0, 0, :]
			ROIs = ROIs_padded

		[P_cls, P_regr] = model_classifier.predict([F, ROIs])

		for ii in range(P_cls.shape[1]):

			if np.max(P_cls[0, ii, :]) < bbox_threshold: #or np.argmax(P_cls[0, ii, :]) == (P_cls.shape[2] - 1):
				print("no boxes detected")
				continue
			cls_name = class_mapping[np.argmax(P_cls[0, ii, :])]

			if cls_name not in bboxes:
				bboxes[cls_name] = []
				probs[cls_name] = []

			(x, y, w, h) = ROIs[0, ii, :]

			cls_num = np.argmax(P_cls[0, ii, :])
			try:
				(tx, ty, tw, th) = P_regr[0, ii, 4*cls_num:4*(cls_num+1)]
				tx /= C.classifier_regr_std[0]
				ty /= C.classifier_regr_std[1]
				tw /= C.classifier_regr_std[2]
				th /= C.classifier_regr_std[3]
				x, y, w, h = roi_helpers.apply_regr(x, y, w, h, tx, ty, tw, th)
			except:
				pass
			bboxes[cls_name].append([C.rpn_stride*x, C.rpn_stride*y, C.rpn_stride*(x+w), C.rpn_stride*(y+h)])
			probs[cls_name].append(np.max(P_cls[0, ii, :]))
	
	for keyid in class_mapping:   
		key = class_mapping[keyid]
		if key not in bboxes or key == "bg":
			all_boxes[keyid][idx] = empty_array
			continue
		else:
			print("detections of ", key)
		if key == "bg":
			continue

		bbox = np.array(bboxes[key])
        

		new_boxes, new_probs = roi_helpers.non_max_suppression_fast(bbox, np.array(probs[key]), overlap_thresh=0.45)
		all_dets = []
		for jk in range(new_boxes.shape[0]):
			(x1, y1, x2, y2) = new_boxes[jk,:]
			(real_x1, real_y1, real_x2, real_y2) = get_real_coordinates(ratio, x1, y1, x2, y2)
			all_dets.append([real_x1, real_y1, real_x2, real_y2, new_probs[jk]])
		all_boxes[keyid][idx] = all_dets
	tottime += time.time()-st        
print(tottime/187)
# Out:
# 187
# inference image path: /N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1006.jpg
# no boxes detected
# no boxes detected
# no boxes detected
# detections of  car
#
# inference image path: /N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1073.jpg
# inference image path: /N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_109.jpg
# no boxes detected
# detections of  car
#
# inference image path: /N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1090.jpg
# inference image path: /N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1103.jpg
# no boxes detected
# detections of  car
#
# inference image path: /N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_1115.jpg
# no boxes detected
# no boxes detected
# detections of  car
#
# inference image path: /N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_112.jpg
# detections of  car
#
# inference image path: /N/u/imtiazahmad/VOC/test/VOCdevkit/VOC2007/JPEGImages/102nd_
#  [[134, 230, 211, 287, 0.5501827], [1094, 326, 1228, 383, 0.51092947]],
#  [[825, 326, 863, 345, 0.89249873],
#   [844, 326, 883, 345, 0.8821076],
#   [940, 383, 998, 422, 0.75568765],
#   [806, 307, 883, 345, 0.6540051]],
#  [[921, 383, 979, 422, 0.82533634],
#   [959, 460, 1017, 499, 0.6533037],
#   [940, 441, 998, 499, 0.5846219]],
#  [[499, 268, 595, 326, 0.5787443], [748, 287, 806, 326, 0.5482336]],
#  array([], shape=(0, 5), dtype=float64),
#  [[153, 326, 249, 364, 0.6425822],
#   [1132, 230, 1151, 249, 0.61356324],
#   [1151, 326, 1267, 383, 0.5912458],
#   [921, 345, 1036, 403, 0.5818964],
#   [0, 249, 38, 268, 0.5391728],
#   [0, 230, 38, 287, 0.5101251],
#   [902, 364, 979, 403, 0.5059168]],
#  array([], shape=(0, 5), dtype=float64),
#  [[518, 211, 595, 249, 0.8891407],
#   [479, 172, 575, 249, 0.80146307],
#   [307, 115, 403, 153, 0.77911687],
#   [710, 268, 787, 307, 0.76752824],
#   [422, 134, 537, 191, 0.7627782],
#   [441, 153, 537, 211, 0.7439347],
#   [691, 575, 806, 652, 0.7155312],
#   [787, 595, 844, 633, 0.69157124],
#   [671, 230, 787, 307, 0.66359335],
#   [748, 575, 863, 633, 0.66335213],
#   [460, 211, 575, 268, 0.6008617],
#   [652, 249, 748, 307, 0.59479314],
#   [403, 134, 479, 191, 0.58169097],
#   [287, 115, 345, 153, 0.5806719],
#   [710, 614, 863, 671, 0.5318484],
#   [499, 191, 595, 230, 0.5240769],
#   [787, 671, 883, 710, 0.5135823],
#   [441, 134, 518, 172, 0.5063216]],
#  [[767, 345, 844, 383, 0.9002346],
#   [767, 364, 825, 383, 0.8519742],
#   [595, 364, 671, 403, 0.84521264],
#   [1036, 345, 1094, 364, 0.83704156],
#   [595, 383, 652, 403, 0.7947608],
#   [998, 326, 1094, 364, 0.7714865],
#   [748, 345, 806, 383, 0.7534107],
#   [614, 364, 671, 383, 0.701666],
#   [633, 364, 691, 403, 0.6886383],
#   [0, 383, 57, 422, 0.68761],
#   [287, 364, 364, 403, 0.6829358],
#   [575, 364, 633, 403, 0.6442186],
#   [691, 326, 729, 345, 0.5942882],
#   [1113, 345, 1190, 383, 0.5934063],
#   [1094, 345, 1171, 364, 0.552817],
#   [0, 403, 38, 441, 0.5349472],
#   [787, 326, 863, 364, 0.5330416],
#   [1132, 326, 1209, 364, 0.5320042],
#   [307, 383, 383, 422, 0.52901846]],
#  [[652, 326, 710, 345, 0.71879905], [671, 307, 710, 345, 0.5904318]],
#  array([], shape=(0, 5), dtype=float64),
#  [[691, 364, 729, 403, 0.90259385],
#   [902, 460, 959, 499, 0.8868028],
#   [499, 326, 575, 364, 0.8562474],
#   [671, 422, 729, 460, 0.8499409],
#   [671, 383, 748, 441, 0.8186469],
#   [863, 460, 959, 518, 0.8171769],
#   [710, 441, 748, 460, 0.74901766],
#   [537, 326, 595, 364, 0.7375315],
#   [825, 652, 902, 710, 0.7300433],
#  [[383, 307, 441, 345, 0.70058966],
#   [403, 326, 441, 345, 0.69584584],
#   [1075, 307, 1113, 326, 0.6839924],
#   [595, 326, 633, 345, 0.6461598],
#   [844, 307, 902, 345, 0.6261785],
#   [1209, 307, 1267, 345, 0.6056512],
#   [383, 307, 422, 326, 0.55529237],
#   [575, 307, 633, 345, 0.5449955],
#   [748, 307, 806, 345, 0.5348129],
#   [959, 326, 1017, 345, 0.5001333]],
#  [[1036, 230, 1075, 268, 0.8550502],
#   [748, 345, 863, 383, 0.8501766],
#   [441, 422, 537, 460, 0.8422449],
#   [1171, 172, 1209, 211, 0.8297488],
#   [556, 422, 633, 460, 0.82444495],
#   [921, 287, 979, 307, 0.8166641],
#   [902, 307, 959, 326, 0.8047412],
#   [710, 345, 806, 383, 0.79276735],
#   [902, 268, 959, 326, 0.79218227],
#   [1190, 172, 1209, 191, 0.77723765],
#   [499, 403, 575, 460, 0.7736154],
#   [979, 230, 1017, 268, 0.7638383],
#   [537, 422, 652, 479, 0.7564058],
#   [595, 422, 671, 460, 0.7471492],
#   [460, 403, 537, 441, 0.7354732],
#   [1151, 191, 1190, 211, 0.69790936],
#   [1209, 134, 1267, 172, 0.6633071],
#   [518, 383, 614, 460, 0.61756796],
#   [691, 115, 729, 134, 0.6148101],
#   [1055, 230, 1113, 268, 0.60454667],
#   [940, 249, 979, 268, 0.59720564],
#   [1094, 211, 1132, 249, 0.59657377],
#   [1113, 211, 1171, 249, 0.56943494],
#   [710, 326, 806, 364, 0.56732315],
#   [1132, 191, 1190, 230, 0.53725797],
#   [422, 403, 499, 441, 0.5220016],
#   [748, 326, 844, 364, 0.5166857],
#   [1247, 134, 1267, 153, 0.50881565],
#   [883, 287, 940, 326, 0.50236934]],
#  array([], shape=(0, 5), dtype=float64),
#  [[1132, 307, 1190, 345, 0.84715044],
#   [1151, 326, 1190, 345, 0.7321074],
#   [1113, 287, 1209, 345, 0.7224319],
#   [710, 441, 844, 499, 0.7204851],
#   [1094, 307, 1171, 345, 0.6932203],
#   [1171, 307, 1209, 326, 0.65492046],
#   [787, 441, 902, 479, 0.6240291],
#   [57, 153, 191, 211, 0.5348026],
#   [691, 460, 767, 499, 0.530148],
#   [0, 153, 134, 191, 0.51922405],
#   [0, 134, 153, 211, 0.5177028]],
#  [[595, 403, 614, 422, 0.840793],
#   [633, 230, 652, 249, 0.8313838],
#   [652, 268, 691, 287, 0.8275737],
#   [652, 230, 671, 249, 0.81595904],
#   [671, 211, 691, 230, 0.78083956],
#   [633, 307, 671, 326, 0.76635176],
#   [614, 211, 652, 249, 0.7612727],
#   [633, 211, 652, 230, 0.7607845],
#   [537, 460, 595, 479, 0.755254],
#   [0, 307, 38, 364, 0.71423334],
#   [652, 287, 691, 307, 0.71167815],
#   [537, 441, 614, 479, 0.6810698],
#   [691, 211, 710, 230, 0.62897253],
#   [556, 383, 614, 422, 0.6226468],
#   [0, 326, 76, 364, 0.6186767],
#   [652, 249, 671, 268, 0.60333407],
#   [575, 383, 614, 403, 0.59384245],
#   [460, 172, 518, 211, 0.66399664],
#   [422, 172, 460, 191, 0.58805126],
#   [499, 191, 556, 230, 0.5879886],
#   [422, 153, 460, 172, 0.50129247]],
#  [[691, 383, 767, 422, 0.8963819],
#   [614, 422, 671, 460, 0.8872634],
#   [863, 172, 921, 211, 0.8797223],
#   [863, 134, 902, 153, 0.8609051],
#   [863, 191, 921, 230, 0.8573355],
#   [652, 383, 729, 422, 0.8274485],
#   [863, 115, 921, 153, 0.80590147],
#   [710, 287, 787, 326, 0.801755],
#   [902, 95, 959, 134, 0.8012033],
#   [844, 134, 902, 172, 0.79787654],
#   [883, 134, 921, 153, 0.7707257],
#   [691, 287, 767, 345, 0.7681479],
#   [595, 422, 691, 479, 0.7681274],
#   [671, 383, 748, 441, 0.76292396],
#   [883, 115, 921, 134, 0.7590717],
#   [825, 191, 902, 230, 0.7288773],
#   [729, 307, 806, 345, 0.70400375],
#   [902, 38, 959, 57, 0.6909943],
#   [710, 268, 806, 345, 0.6757411],
#   [902, 0, 998, 38, 0.6112231],
#   [633, 383, 710, 441, 0.594555],
#   [921, 0, 979, 19, 0.5759635],
#   [863, 153, 921, 191, 0.5543988],
#   [556, 422, 633, 460, 0.5356662],
#   [230, 0, 364, 38, 0.5316276],
#   [575, 441, 652, 479, 0.5274328],
#   [844, 134, 883, 153, 0.51852494],
#   [883, 19, 959, 38, 0.5019084]],
#  array([], shape=(0, 5), dtype=float64),
#  [[614, 268, 691, 326, 0.8768451],
#   [633, 287, 710, 326, 0.86700785],
#   [575, 230, 614, 268, 0.8592467],
#   [595, 230, 652, 268, 0.8433964],
#   [691, 191, 729, 230, 0.83800405],
#   [633, 268, 729, 307, 0.8323008],
#   [441, 364, 575, 422, 0.82767934],
#   [460, 211, 537, 249, 0.8232915],
#   [441, 211, 479, 249, 0.82110053],
#   [556, 345, 652, 383, 0.8150161],
#   [499, 345, 595, 383, 0.80963904],
#   [499, 364, 556, 403, 0.7910719],
#   [518, 326, 633, 383, 0.7833137],
#   [0, 460, 134, 518, 0.77341855],
#   [499, 211, 575, 249, 0.7666286],
#   [460, 211, 518, 230, 0.7621382],
#   [633, 249, 710, 287, 0.7562661],
#   [479, 191, 537, 230, 0.7473435],
#   [518, 172, 575, 211, 0.7436666],
#   [902, 191, 959, 230, 0.730742],
#   [479, 172, 556, 211, 0.7297975],
#   [633, 307, 691, 345, 0.72714853],
#   [556, 364, 652, 403, 0.70729584],
#   [403, 364, 499, 403, 0.6984693],
#   [537, 230, 595, 268, 0.69485927],
#   [575, 307, 652, 364, 0.65345806],
#   [595, 249, 652, 287, 0.65086424],
#   [556, 326, 614, 364, 0.64855546],
#   [0, 422, 153, 537, 0.64123046],
#   [403, 307, 652, 403, 0.6188682],
#   [441, 191, 499, 230, 0.61200964],
#   [537, 211, 595, 249, 0.60794306],
#   [422, 230, 479, 249, 0.57055694],
#   [1132, 172, 1190, 211, 0.56838757],
#   [441, 268, 691, 383, 0.56552047],
#   [383, 345, 614, 441, 0.54589295],
#  [[211, 307, 249, 326, 0.7264911],
#   [191, 307, 249, 345, 0.7054647],
#   [326, 326, 364, 345, 0.6172592],
#   [230, 326, 268, 345, 0.55836964],
#   [307, 307, 345, 345, 0.51289713]],
#  [[249, 460, 422, 518, 0.71719974],
#   [268, 441, 479, 537, 0.6864099],
#   [268, 479, 383, 537, 0.60498875],
#   [863, 153, 940, 191, 0.601018],
#   [1113, 268, 1209, 326, 0.5682108],
#   [1190, 268, 1286, 307, 0.55010444],
#   [191, 0, 307, 38, 0.54489565],
#   [1132, 230, 1267, 307, 0.5282295],
#   [1190, 249, 1267, 364, 0.5228604],
#   [1171, 249, 1267, 287, 0.5154358],
#   [729, 287, 825, 345, 0.5149005],
#   [345, 479, 460, 537, 0.510408],
#   [595, 537, 671, 575, 0.50025487]],
#  [[729, 364, 825, 403, 0.8836223],
#   [134, 403, 230, 441, 0.8788988],
#   [364, 364, 479, 403, 0.865234],
#   [767, 326, 863, 383, 0.8433018],
#   [729, 345, 883, 403, 0.8246312],
#   [76, 383, 191, 441, 0.7671508],
#   [1113, 326, 1228, 364, 0.7181751],
#   [1132, 345, 1247, 383, 0.7083391],
#   [345, 364, 422, 403, 0.70771724],
#   [806, 326, 883, 364, 0.7075316],
#   [95, 403, 191, 460, 0.68170965],
#   [76, 403, 153, 441, 0.6807317],
#   [806, 345, 883, 383, 0.61293197],
#   [748, 326, 825, 364, 0.60999656],
#   [691, 364, 767, 403, 0.6097157],
#   [403, 383, 479, 422, 0.57417303],
#   [748, 307, 883, 364, 0.5387627],
#   [633, 633, 748, 691, 0.5223619],
#   [940, 326, 998, 364, 0.5126978]],
#  array([], shape=(0, 5), dtype=float64),
#  [[595, 326, 633, 345, 0.7831109], [575, 307, 614, 345, 0.61080486]],
#  [[883, 211, 998, 287, 0.78058136],
#   [883, 230, 959, 268, 0.75860274],
#   [921, 230, 1055, 287, 0.7398247],
#   [595, 345, 710, 422, 0.735195],
#   [403, 383, 537, 479, 0.72345006],
#   [499, 345, 691, 460, 0.72174233],
#   [460, 403, 633, 499, 0.710142],
#   [556, 326, 729, 441, 0.7007669],
#   [403, 403, 499, 460, 0.687084],
#   [921, 191, 1075, 268, 0.67911226],
#   [556, 383, 691, 441, 0.63313967],
#   [115, 460, 345, 575, 0.63120085],
#   [76, 479, 230, 575, 0.62659234],
#   [883, 249, 940, 287, 0.6175358],
#   [95, 479, 211, 537, 0.6142729],
#   [383, 345, 633, 499, 0.6081144],
#   [134, 499, 307, 595, 0.607336],
#   [633, 345, 691, 383, 0.5873072],
#   [863, 172, 1055, 287, 0.57441616],
#   [95, 518, 191, 575, 0.55613786],
#   [499, 307, 671, 403, 0.54745257],
#   [249, 499, 345, 556, 0.54416263],
#   [518, 326, 633, 383, 0.5436792]],
#  [[1036, 287, 1190, 422, 0.5601975],
#   [1075, 307, 1171, 383, 0.559242],
#   [1094, 287, 1171, 345, 0.55168253],
#   [998, 268, 1190, 364, 0.52350676]],
#  [[268, 307, 422, 364, 0.8132138],
#   [287, 287, 441, 345, 0.74731934],
#   [383, 345, 518, 422, 0.7459187],
#   [364, 364, 422, 403, 0.7313142],
#   [383, 364, 575, 441, 0.7266328],
#   [345, 326, 460, 403, 0.7262585],
#   [383, 364, 460, 403, 0.7159206],
#   [345, 326, 422, 364, 0.6923442],
#   [287, 326, 403, 383, 0.6646936],
#   [230, 287, 345, 345, 0.6388089],
#   [479, 383, 652, 460, 0.630597],
#   [307, 287, 614, 403, 0.6007748],
#   [383, 345, 671, 460, 0.57013255],
#   [556, 383, 633, 441, 0.54231155]],
#  [[806, 307, 883, 345, 0.86739147],
#   [825, 307, 863, 326, 0.79832643],
#   [806, 326, 863, 364, 0.78965896],
#   [671, 383, 767, 441, 0.77847165],
#   [441, 460, 595, 518, 0.7766072],
#   [767, 326, 844, 364, 0.7715818],
#   [422, 479, 556, 537, 0.7662185],
#   [518, 403, 614, 460, 0.7573054],
#   [825, 307, 921, 364, 0.732912],
#   [556, 422, 652, 479, 0.7239796],
#   [710, 345, 806, 403, 0.72326076],
#   [652, 403, 729, 441, 0.7232285],
#   [403, 460, 499, 518, 0.713637],
#   [748, 345, 825, 383, 0.71083695],
#   [556, 403, 633, 441, 0.7064605],
#   [537, 383, 652, 460, 0.7050693],
#   [844, 307, 883, 326, 0.7020993],
#   [633, 364, 748, 441, 0.7017715],
#   [0, 537, 191, 710, 0.6890139],
#   [652, 383, 729, 422, 0.68750185],
#   [499, 479, 575, 518, 0.6753505],
#   [95, 556, 211, 614, 0.6717415],
#   [806, 287, 883, 326, 0.66199696],
#   [0, 518, 95, 729, 0.65146667],
#   [76, 518, 191, 633, 0.6509346],
#   [787, 307, 844, 345, 0.6369132],
#   [787, 345, 844, 383, 0.59267527],
#   [863, 307, 921, 345, 0.5920287],
#   [825, 345, 863, 383, 0.58869636],
#   [0, 518, 191, 575, 0.58515275],
#   [0, 614, 153, 710, 0.5833041],
#   [0, 556, 76, 633, 0.5818666],
#   [115, 575, 172, 614, 0.5657247],
#   [902, 287, 959, 326, 0.56240577],
#   [691, 345, 767, 383, 0.5606865],
#   [0, 479, 211, 614, 0.53395796],
#   [460, 422, 595, 499, 0.52765757],
#   [729, 364, 787, 403, 0.51035124]],
#  [[1190, 230, 1247, 249, 0.83482575],
#   [1113, 249, 1190, 287, 0.8303674],
#   [1151, 230, 1247, 287, 0.8048622],
#   [1209, 211, 1267, 249, 0.7943798],
#   [979, 345, 1151, 422, 0.7730335],
#   [825, 403, 921, 460, 0.76857066],
#   [844, 383, 979, 479, 0.7620868],
#   [940, 326, 1075, 383, 0.76080084],
#   [1055, 307, 1190, 364, 0.75101876],
#   [1113, 230, 1171, 268, 0.74429303],
#   [1094, 307, 1171, 345, 0.7410926],
#   [1113, 268, 1171, 307, 0.7352473],
#   [1017, 307, 1113, 364, 0.7351787],
#   [1075, 268, 1209, 326, 0.73056066],
#   [1132, 249, 1209, 307, 0.72652996],
#   [883, 345, 1132, 460, 0.7253861],
#   [921, 345, 1017, 383, 0.7248546],
#   [1036, 326, 1113, 383, 0.7233004],
#   [1055, 383, 1113, 422, 0.7115609],
#   [633, 460, 787, 537, 0.71049136],
#   [1055, 287, 1151, 345, 0.7099107],
#   [595, 460, 691, 518, 0.7094077],
#   [1036, 364, 1132, 422, 0.70491284],
#   [1190, 249, 1228, 287, 0.6804925],
#   [1075, 326, 1132, 364, 0.67759675],
#   [921, 364, 1036, 422, 0.67696905],
#   [921, 287, 1171, 441, 0.67050713],
#   [883, 422, 998, 479, 0.66595924],
#   [1171, 268, 1209, 287, 0.6595373],
#   [1228, 230, 1267, 249, 0.6259832],
#   [1055, 307, 1113, 345, 0.6196282],
#   [575, 441, 710, 499, 0.6100006],
#   [1017, 230, 1247, 345, 0.609959],
#   [1094, 249, 1151, 287, 0.60376304],
#   [1228, 211, 1267, 230, 0.5939081],
#   [575, 460, 729, 556, 0.59322715],
#   [671, 422, 787, 499, 0.5518431],
#   [710, 499, 787, 537, 0.54141986],
#   [921, 268, 1190, 364, 0.53969276],
#   [1171, 211, 1228, 249, 0.53382385],
#   [979, 383, 1075, 441, 0.53042334],
#   [1075, 268, 1132, 307, 0.52723306]],
#  [[1171, 211, 1267, 268, 0.873799],
#   [691, 326, 825, 422, 0.82519716],
#   [767, 287, 863, 326, 0.8109196],
#   [748, 364, 844, 403, 0.8055811],
#   [748, 249, 902, 307, 0.77875596],
#   [710, 287, 825, 345, 0.77831495],
#   [710, 307, 863, 383, 0.76659733],
#   [710, 249, 844, 326, 0.7646928],
#   [671, 345, 748, 403, 0.75204104],
#   [1190, 211, 1247, 249, 0.7309809],
#   [806, 268, 902, 307, 0.728387],
#   [748, 307, 825, 364, 0.7239052],
#   [671, 287, 902, 403, 0.6979978],
#   [806, 249, 883, 287, 0.68423915],
#   [767, 307, 863, 345, 0.64039695],
#   [1190, 230, 1267, 287, 0.58932227],
#   [652, 287, 844, 499, 0.5343855],
#   [729, 191, 921, 403, 0.5183436],
#   [748, 383, 863, 441, 0.51111364]],
#  [[479, 326, 537, 345, 0.623059]],
#  [[748, 268, 844, 307, 0.6856447],
#   [787, 268, 883, 307, 0.56259215],
#   [767, 268, 921, 326, 0.54875886]],
#  [[326, 518, 383, 537, 0.76173526],
#   [307, 499, 383, 537, 0.6989459],
#   [806, 230, 844, 249, 0.6945148],
#   [556, 422, 614, 460, 0.6889175],
#   [710, 364, 748, 383, 0.674701],
#   [345, 499, 403, 537, 0.60745645],
#   [806, 211, 825, 230, 0.54529285],
#   [710, 383, 748, 403, 0.50368303]],
#  [[556, 172, 652, 230, 0.8341267],
#   [537, 134, 633, 211, 0.67144483],
#   [518, 153, 595, 211, 0.67042345],
#   [595, 191, 652, 230, 0.53921276],
#   [537, 153, 614, 191, 0.522185]],
#  array([], shape=(0, 5), dtype=float64),
#  [[863, 211, 921, 230, 0.8652423],
#   [1228, 191, 1267, 211, 0.8348452],
#   [979, 211, 1036, 230, 0.82960737],
#   [307, 211, 383, 268, 0.8140072],
#   [326, 211, 422, 287, 0.8061195],
#   [959, 191, 1036, 230, 0.80228466],
#   [748, 191, 806, 230, 0.7953617],
#   [1075, 191, 1132, 230, 0.78911084],
#   [268, 268, 403, 345, 0.7779117],
#   [345, 249, 479, 364, 0.7761573],
#   [307, 230, 403, 307, 0.76659673],
#   [307, 191, 403, 249, 0.7656727],
#   [268, 287, 460, 364, 0.7649837],
#   [460, 211, 518, 249, 0.7588461],
#   [403, 191, 518, 249, 0.75133747],
#   [364, 230, 441, 307, 0.7499688],
#   [863, 191, 940, 230, 0.7436302],
#   [383, 211, 479, 249, 0.7401317],
#   [575, 191, 633, 230, 0.73638177],
#   [441, 191, 518, 230, 0.7320019],
#   [537, 211, 595, 230, 0.7066181],
#   [1055, 211, 1113, 230, 0.7050036],
#   [1171, 191, 1209, 211, 0.6939184],
#   [1190, 191, 1228, 230, 0.6928287],
#   [345, 191, 441, 249, 0.68706167],
#   [710, 191, 787, 230, 0.6865531],
#   [710, 268, 863, 345, 0.68507767],
#   [537, 191, 614, 230, 0.66982436],
#   [230, 230, 518, 345, 0.662776],
#   [729, 287, 902, 364, 0.64817435],
#   [326, 172, 460, 268, 0.64257187],
#   [479, 230, 518, 249, 0.60933673],
#   [249, 268, 499, 403, 0.600533],
#   [1209, 172, 1267, 230, 0.5974637],
#   [998, 191, 1055, 230, 0.58312124],
#   [614, 287, 825, 364, 0.5678189],
#   [844, 191, 902, 230, 0.5614585],
#   [633, 287, 979, 441, 0.54707676],
#   [556, 211, 614, 249, 0.54310364],
#   [1151, 191, 1190, 230, 0.53833216],
#   [710, 307, 883, 422, 0.5344042],
#   [652, 268, 767, 326, 0.52394867],
#   [268, 172, 499, 307, 0.5230566],
#   [479, 191, 537, 230, 0.52291816],
#   [422, 191, 479, 230, 0.51286554]],
#  [[249, 249, 345, 287, 0.60437757], [287, 230, 403, 287, 0.53007936]],
#  [[1017, 230, 1075, 268, 0.84503615],
#   [729, 326, 825, 364, 0.83803916],
#   [460, 422, 575, 479, 0.83795637],
#   [441, 422, 537, 460, 0.835164],
#   [998, 211, 1094, 268, 0.8282133],
#   [556, 383, 652, 441, 0.8071478],
#   [787, 287, 902, 345, 0.8019309],
#   [76, 479, 249, 556, 0.7969978],
#   [1209, 191, 1267, 230, 0.7945464],
#   [479, 403, 575, 460, 0.79423285],
#   [537, 403, 671, 460, 0.79394305],
#   [825, 287, 902, 326, 0.792474],
#   [211, 479, 345, 537, 0.7869561],
#   [191, 479, 287, 518, 0.7830769],
#   [230, 460, 326, 518, 0.78148],
#   [1036, 249, 1113, 268, 0.77829844],
#   [787, 307, 863, 364, 0.77711827],
#   [940, 249, 998, 287, 0.7754028],
#   [57, 499, 172, 556, 0.7307281],
#   [518, 383, 614, 441, 0.72939813],
#   [614, 403, 671, 441, 0.7174796],
#   [422, 422, 518, 499, 0.7095741],
#   [844, 268, 940, 307, 0.7028954],
#   [825, 307, 902, 345, 0.7015951],
#   [1113, 191, 1190, 230, 0.69854933],
#   [134, 460, 383, 575, 0.6930873],
#   [1036, 211, 1094, 249, 0.69122154],
#   [1094, 211, 1171, 249, 0.684285],
#   [998, 249, 1055, 268, 0.68238336],
#   [172, 499, 268, 537, 0.6682118],
#   [825, 249, 959, 326, 0.66769505],
#   [979, 230, 1036, 268, 0.6628115],
#   [422, 422, 479, 460, 0.6617664],
#   [403, 403, 652, 499, 0.6408467],
#   [1094, 211, 1151, 230, 0.6385605],
#   [499, 441, 595, 479, 0.63805807],
#   [921, 249, 1017, 307, 0.63293046],
#   [556, 383, 614, 422, 0.63239324],
#   [537, 422, 614, 460, 0.6173928],
#   [499, 364, 748, 479, 0.6082727],
#   [191, 460, 287, 499, 0.5978288],
#   [172, 518, 268, 556, 0.597798],
#   [979, 249, 1036, 287, 0.59481424],
#   [1055, 230, 1113, 268, 0.59479076],
#   [940, 230, 1017, 268, 0.5921123],
#   [863, 230, 979, 307, 0.58649206],
#   [57, 479, 153, 537, 0.5856967],
#   [998, 211, 1055, 249, 0.5837728],
#   [575, 422, 633, 460, 0.5834306],
#   [595, 422, 671, 460, 0.5672858],
#   [1190, 172, 1267, 249, 0.5512595],
#   [95, 518, 230, 575, 0.5408139],
#   [767, 345, 844, 383, 0.5377396],
#   [57, 441, 307, 537, 0.53324234],
#   [211, 441, 326, 499, 0.53093183],
#   [537, 364, 652, 422, 0.51916146],
#   [1017, 191, 1113, 249, 0.5147892],
#   [134, 460, 230, 518, 0.5029286]],
#  [[479, 211, 518, 230, 0.87997174],
# ...
#   [249, 499, 307, 518, 0.52478653]],
#  [[998, 307, 1132, 364, 0.67762154],
#   [1055, 307, 1113, 364, 0.63982564],
#   [863, 345, 1017, 403, 0.6360354],
#   [921, 287, 1132, 383, 0.5929442],
#   [595, 364, 787, 479, 0.5716346],
#   [556, 422, 671, 460, 0.5651911],
#   [652, 383, 825, 441, 0.5573193],
#   [537, 403, 729, 479, 0.5557171],
#   [479, 422, 652, 479, 0.5504586],
#   [863, 307, 1094, 422, 0.5496859],
#   [710, 383, 787, 441, 0.531348],
#   [499, 441, 614, 499, 0.5229137],
#   [921, 364, 1017, 403, 0.5221388],
#   [863, 345, 940, 383, 0.50700885],
#   [940, 326, 1094, 383, 0.5026686]],
#  [[614, 0, 691, 38, 0.86207175],
#   [537, 249, 671, 307, 0.8416017],
#   [787, 268, 902, 326, 0.8181295],
#   [787, 249, 883, 307, 0.8141894],
#   [556, 230, 671, 287, 0.807841],
#   [575, 0, 671, 57, 0.7950071],
#   [499, 230, 633, 307, 0.7435784],
#   [844, 287, 921, 326, 0.68168926],
#   [767, 268, 844, 326, 0.66438866],
#   [595, 249, 671, 287, 0.65129614],
#   [959, 575, 1151, 671, 0.631749],
#   [825, 249, 883, 287, 0.6274329],
#   [767, 211, 902, 326, 0.59241575],
#   [921, 575, 1075, 652, 0.5923253],
#   [537, 268, 652, 326, 0.57489705],
#   [959, 556, 1094, 614, 0.56641],
#   [921, 556, 1036, 614, 0.50942934],
#   [767, 230, 883, 287, 0.5059864]],
#  [[633, 268, 671, 287, 0.9405789],
#   [614, 268, 652, 287, 0.89365196],
#   [595, 230, 652, 249, 0.8857617],
#   [575, 383, 614, 403, 0.8835013],
#   [556, 307, 748, 422, 0.63878345],
#   [1055, 0, 1209, 38, 0.6253651],
#   [844, 134, 1075, 249, 0.603722],
#   [537, 441, 633, 499, 0.6017378],
#   [671, 307, 825, 422, 0.601322],
#   [652, 287, 806, 364, 0.5951519],
#   [959, 0, 1113, 38, 0.5785339],
#   [518, 326, 825, 460, 0.5753922],
#   [787, 134, 959, 230, 0.57509524],
#   [479, 441, 652, 595, 0.5698477],
#   [1017, 19, 1151, 76, 0.5692569],
#   [844, 115, 998, 211, 0.5661661],
#   [1094, 0, 1247, 76, 0.563771],
#   [556, 268, 787, 383, 0.56186044],
#   [364, 422, 614, 575, 0.55094236],
#   [518, 422, 614, 479, 0.5487056],
#   [537, 268, 729, 499, 0.5444985],
#   [460, 403, 729, 537, 0.5408672],
#   [844, 95, 1094, 191, 0.531922],
#   [1132, 0, 1247, 38, 0.52582127],
#   [979, 134, 1075, 211, 0.51623553]],
#  array([], shape=(0, 5), dtype=float64),
#  [[499, 134, 537, 153, 0.5910154],
#   [537, 134, 575, 153, 0.52551204],
#   [518, 134, 556, 153, 0.50590956]],
#  [[710, 249, 883, 345, 0.68500453],
#   [691, 268, 806, 345, 0.65665084],
#   [787, 249, 940, 383, 0.6547166],
#   [729, 287, 902, 364, 0.5614087],
#   [1171, 57, 1209, 95, 0.5507315],
#   [767, 230, 921, 307, 0.5484895],
#   [844, 249, 940, 307, 0.54127586],
#   [691, 230, 825, 307, 0.50899804]],
#  [[1171, 249, 1286, 307, 0.5828931],
#   [1132, 230, 1286, 326, 0.5700918],
#   [1094, 211, 1190, 287, 0.55610466],
#   [1209, 230, 1267, 287, 0.51877546],
#   [1171, 230, 1247, 287, 0.51765114]],
#  [[575, 191, 671, 268, 0.6608087],
#   [556, 230, 691, 268, 0.6469174],
#   [614, 230, 671, 249, 0.6326734],
#   [479, 211, 575, 268, 0.5883251],
#   [499, 172, 652, 249, 0.50138694]],
#  [[575, 211, 614, 230, 0.6031151],
#   [249, 249, 326, 307, 0.56505215],
#   [211, 268, 345, 307, 0.517785],
#   [230, 230, 345, 326, 0.5050541]],
#  array([], shape=(0, 5), dtype=float64),
#  [[38, 153, 153, 191, 0.8573593],
#   [76, 134, 153, 172, 0.8237041],
#   [115, 153, 172, 191, 0.8080145],
#   [38, 115, 172, 191, 0.79655063],
#   [614, 364, 767, 460, 0.66012603],
#   [614, 364, 691, 422, 0.61241657],
#   [691, 383, 825, 441, 0.597623],
#   [595, 383, 691, 441, 0.57939136],
#   [748, 403, 825, 441, 0.5613087],
#   [748, 383, 825, 422, 0.52531695],
#   [76, 38, 153, 76, 0.5030881]],
#  [[825, 38, 863, 57, 0.8247923],
#   [633, 230, 767, 307, 0.7482325],
#   [767, 19, 844, 76, 0.73474056],
#   [691, 268, 787, 307, 0.70805943],
#   [825, 19, 883, 57, 0.66052055],
#   [652, 249, 729, 287, 0.65735906],
#   [691, 249, 767, 287, 0.6521374],
#   [748, 19, 825, 57, 0.6387154],
#   [806, 19, 863, 38, 0.5255928]],
#  [[1036, 249, 1094, 287, 0.8076194],
#   [287, 326, 364, 364, 0.74688715],
#   [268, 307, 383, 383, 0.74275404],
#   [326, 345, 422, 383, 0.68872887],
#   [326, 326, 403, 364, 0.6187269],
#   [268, 326, 326, 364, 0.5599404]],
#  [[595, 345, 652, 364, 0.8902597],
#   [787, 326, 863, 364, 0.87077063],
#   [595, 326, 671, 364, 0.8517643],
#   [671, 307, 767, 364, 0.7453531],
#   [767, 307, 844, 364, 0.67730993],
#   [595, 326, 633, 345, 0.67005336],
#   [652, 326, 729, 364, 0.6593407],
#   [575, 326, 614, 345, 0.64623123]],
#  [[767, 326, 825, 364, 0.66438395],
#   [575, 268, 671, 326, 0.64000684],
#   [537, 268, 633, 326, 0.6080449],
#   [556, 249, 671, 307, 0.5623181],
#   [595, 326, 691, 364, 0.5126562],
#   [575, 307, 652, 345, 0.50063306]],
#  [[460, 422, 499, 441, 0.7829809],
#   [556, 364, 595, 383, 0.7367587],
#   [614, 326, 652, 345, 0.72201633],
#   [1151, 230, 1190, 249, 0.7160736],
#   [998, 268, 1036, 287, 0.71381694],
#   [460, 364, 499, 383, 0.7032869],
#   [364, 403, 403, 422, 0.70048875],
#   [499, 364, 537, 383, 0.660322],
#   [921, 268, 959, 287, 0.6562961],
#   [403, 403, 441, 441, 0.651228],
#   [1171, 230, 1209, 249, 0.6388521],
#   [441, 403, 499, 441, 0.6283304],
#   [422, 403, 460, 441, 0.6084012],
#   [652, 326, 691, 364, 0.5950117],
#   [595, 307, 633, 345, 0.5911456],
#   [441, 345, 499, 383, 0.57078594],
#   [537, 364, 575, 383, 0.5637563],
#   [633, 326, 671, 364, 0.56359917],
#   [345, 403, 403, 441, 0.53578377],
#   [364, 422, 403, 441, 0.51343745],
#   [479, 345, 518, 383, 0.50705534],
#   [383, 403, 422, 441, 0.500129]],
#  [[0, 268, 38, 307, 0.63084817],
#   [441, 383, 499, 422, 0.5921785],
#   [403, 403, 479, 441, 0.58927006],
#   [0, 249, 19, 307, 0.5597902],
#   [422, 403, 499, 460, 0.5502873],
#   [345, 383, 460, 460, 0.5063031]],
#  [[787, 153, 902, 211, 0.6470873],
#   [767, 134, 921, 191, 0.63472855],
#   [134, 249, 211, 287, 0.56507057],
#   [844, 172, 902, 211, 0.53989315],
#   [729, 153, 863, 191, 0.51939034],
#   [134, 268, 211, 307, 0.519042]],
#  [[614, 364, 691, 403, 0.85471255],
#   [595, 364, 671, 422, 0.8431246],
#   [441, 364, 518, 422, 0.8356759],
#   [652, 364, 710, 403, 0.79884446],
#   [460, 364, 537, 403, 0.78992397],
#   [499, 383, 556, 422, 0.786262],
#   [556, 364, 633, 403, 0.7743836],
#   [575, 383, 652, 422, 0.7594254],
#   [614, 364, 729, 422, 0.6980821],
#   [383, 364, 441, 383, 0.6970294],
#   [595, 345, 710, 403, 0.68000484],
#   [671, 403, 844, 479, 0.67933536],
#   [767, 441, 863, 518, 0.6636092],
#   [633, 441, 844, 499, 0.65333354],
#   [537, 383, 614, 422, 0.63799965],
#   [518, 364, 595, 422, 0.62025166],
#   [691, 422, 902, 537, 0.61551017],
#   [614, 422, 787, 537, 0.5692932],
#   [479, 345, 729, 441, 0.5685208],
#   [403, 345, 479, 383, 0.5571501],
#   [633, 460, 767, 518, 0.5543393],
#   [499, 364, 556, 403, 0.5515973],
#   [383, 345, 460, 403, 0.51338166]],
#  [[537, 403, 575, 422, 0.90852404],
#   [499, 364, 537, 383, 0.8522564],
#   [518, 403, 556, 422, 0.85015106],
#   [479, 345, 518, 364, 0.8211067],
#   [460, 345, 499, 364, 0.8162476],
#   [633, 441, 710, 479, 0.79266536],
#   [633, 614, 729, 691, 0.76707417],
#   [614, 422, 691, 460, 0.760645],
#   [575, 595, 691, 671, 0.73978966],
#   [614, 441, 671, 479, 0.7391726],
#   [575, 403, 614, 422, 0.7120044],
#   [575, 441, 652, 479, 0.71177423],
#   [652, 441, 691, 460, 0.7111516],
#   [575, 403, 633, 441, 0.6889259],
#   [556, 460, 614, 479, 0.6823484],
#   [403, 230, 479, 268, 0.6477591],
#   [633, 460, 691, 479, 0.64660275],
#   [518, 403, 575, 441, 0.62903637],
#   [403, 211, 479, 249, 0.62804693],
#   [556, 383, 614, 422, 0.6189241],
#   [691, 403, 729, 422, 0.61861825],
#   [652, 422, 729, 479, 0.6089844],
#   [479, 364, 518, 383, 0.6078824],
#   [383, 211, 460, 268, 0.5980803],
#   [499, 345, 537, 364, 0.5971715],
#   [633, 595, 729, 633, 0.56963223],
#   [422, 211, 499, 268, 0.56764954],
#   [595, 460, 633, 479, 0.5191682]],
#  [[537, 287, 575, 307, 0.7942209],
#   [518, 268, 575, 307, 0.77060145],
#   [556, 268, 614, 307, 0.67074376],
#   [614, 268, 710, 307, 0.6570741],
#   [499, 268, 556, 287, 0.6337241],
#   [556, 287, 595, 307, 0.6028946],
#   [575, 268, 633, 287, 0.573122],
#   [575, 287, 633, 307, 0.5687409],
#   [115, 76, 153, 95, 0.55218464],
#   [191, 115, 230, 153, 0.5495725],
#   [518, 249, 575, 287, 0.54280376],
#   [172, 115, 211, 153, 0.5200553]],
#  [[767, 345, 844, 383, 0.69394886],
#   [844, 345, 902, 383, 0.6843544],
#   [787, 345, 844, 364, 0.5642621],
#   [767, 364, 825, 383, 0.5047354]],
#  [[556, 499, 595, 518, 0.8657192],
#   [537, 499, 575, 518, 0.8077299],
#   [518, 479, 614, 518, 0.76367474],
#   [883, 307, 921, 326, 0.7003166],
#   [825, 364, 863, 383, 0.6465035],
#   [806, 364, 844, 403, 0.6294285],
#   [556, 479, 595, 499, 0.575507],
#   [863, 307, 883, 326, 0.52059525]],
#  [[403, 422, 499, 460, 0.6265011],
#   [364, 422, 479, 479, 0.6201321],
#   [614, 268, 787, 345, 0.5908864],
#   [383, 403, 518, 499, 0.56096405],
#   [1190, 364, 1228, 403, 0.56075025],
#   [691, 268, 863, 345, 0.5574871],
#   [383, 383, 499, 460, 0.52677596],
#   [748, 268, 940, 326, 0.5200697],
#   [844, 249, 998, 307, 0.5134133],
#   [633, 287, 863, 383, 0.5119238],
#   [844, 249, 940, 287, 0.5035414]],
#  [[729, 326, 787, 364, 0.7444589],
#   [729, 345, 787, 383, 0.7020986],
#   [383, 249, 518, 307, 0.6236496],
#   [403, 230, 595, 326, 0.5722938],
#   [460, 249, 614, 307, 0.5668492],
#   [479, 268, 633, 326, 0.5614009],
#   [403, 268, 537, 326, 0.5311235]],
#  [[95, 307, 230, 364, 0.64339143],
#   [76, 326, 211, 383, 0.5876888],
#   [115, 287, 230, 345, 0.5447137],
#   [710, 249, 787, 287, 0.5234356],
#   [57, 287, 211, 403, 0.5178645]],
#  [[1055, 268, 1094, 287, 0.81201255],
#   [710, 345, 729, 364, 0.7884807],
#   [1209, 230, 1247, 249, 0.7757917],
#   [979, 268, 998, 287, 0.74763787],
#   [1036, 268, 1075, 287, 0.7452434],
#   [575, 364, 614, 383, 0.729785],
#   [460, 422, 499, 441, 0.7264468],
#   [671, 326, 729, 364, 0.71200645],
#   [883, 307, 902, 326, 0.7112427],
#   [1190, 230, 1228, 249, 0.7043664],
#   [614, 326, 652, 345, 0.69385695],
#   [518, 364, 556, 383, 0.6778734],
#   [403, 403, 441, 441, 0.63968813],
#   [595, 364, 633, 383, 0.63071793],
#   [633, 326, 671, 345, 0.60203344],
#   [1017, 268, 1055, 287, 0.5812845],
#   [998, 268, 1017, 287, 0.5789782],
#   [787, 307, 825, 326, 0.57387155],
#   [441, 403, 479, 441, 0.5479204],
#   [383, 403, 422, 441, 0.5375555],
#   [345, 403, 403, 422, 0.5353954],
#   [1228, 230, 1267, 249, 0.5266281]],
#  [[556, 307, 671, 364, 0.8337469],
#   [0, 191, 76, 249, 0.7546391],
#   [614, 307, 729, 364, 0.7301881],
#   [595, 307, 671, 345, 0.71414685],
#   [633, 287, 748, 345, 0.69753456],
#   [671, 307, 767, 345, 0.6894723],
#   [767, 0, 902, 19, 0.6705046],
#   [38, 191, 95, 230, 0.6640684],
#   [76, 211, 134, 230, 0.6565377],
#   [95, 191, 153, 230, 0.6196829],
#   [806, 0, 883, 38, 0.61886364],
#   [19, 172, 115, 230, 0.5924149],
#   [748, 0, 863, 38, 0.5687865],
#   [633, 326, 691, 364, 0.5682549],
#   [863, 0, 940, 19, 0.5299866],
#   [0, 172, 115, 287, 0.524199],
#   [633, 287, 710, 326, 0.52298194]],
#  [[38, 383, 211, 441, 0.77537477],
#   [0, 403, 115, 460, 0.73739576],
#   [134, 383, 191, 403, 0.7332131],
#   [825, 249, 921, 307, 0.7076298],
#   [57, 364, 191, 422, 0.7038541],
#   [19, 364, 115, 422, 0.6753899],
#   [19, 345, 230, 460, 0.6495723],
#   [0, 383, 172, 479, 0.6080865],
#   [38, 0, 95, 19, 0.58389884],
#   [748, 230, 902, 287, 0.57406473],
#   [441, 19, 556, 76, 0.56463546],
#   [748, 249, 863, 307, 0.55521697],
#   [403, 38, 518, 95, 0.51783305],
#   [633, 57, 748, 115, 0.5137576],
#   [671, 76, 787, 115, 0.5025673]],
#  [[0, 268, 38, 307, 0.7369103],
#   [422, 383, 479, 422, 0.5974004],
#   [403, 403, 499, 441, 0.58294517],
#   [95, 326, 172, 383, 0.5660391],
#   [364, 383, 479, 460, 0.5539819],
#   [0, 249, 19, 287, 0.54127747],
#   [1132, 0, 1228, 38, 0.5129957]],
#  [[95, 230, 191, 268, 0.6990589],
#   [172, 230, 249, 268, 0.67658967],
#   [57, 211, 211, 268, 0.65464264],
#   [153, 211, 268, 268, 0.6417436],
#   [345, 287, 422, 345, 0.6152866],
#   [326, 307, 403, 345, 0.6106718],
#   [95, 191, 249, 249, 0.57074463],
#   [19, 230, 230, 287, 0.57025653],
#   [0, 191, 326, 307, 0.5055523]],
#  [[422, 153, 633, 249, 0.5889917],
#   [441, 172, 595, 230, 0.5824568],
#   [383, 153, 556, 230, 0.5515988],
#   [499, 153, 671, 211, 0.54362303],
#   [441, 134, 614, 211, 0.52853405],
#   [364, 153, 460, 191, 0.51309705],
#   [326, 134, 691, 230, 0.50475997]],
#  [[806, 153, 921, 211, 0.67704153],
#   [729, 134, 940, 191, 0.63147163],
#   [671, 153, 787, 211, 0.59377867],
#   [710, 153, 844, 191, 0.5908653],
#   [633, 134, 921, 230, 0.57749534],
#   [844, 172, 902, 211, 0.5549197],
#   [729, 172, 844, 211, 0.55125475],
#   [691, 115, 844, 191, 0.5127771],
#   [134, 249, 211, 287, 0.50315493]],
#  [[575, 383, 633, 422, 0.72562736],
#   [863, 364, 902, 403, 0.69561124],
#   [1151, 364, 1190, 383, 0.6754953],
#   [844, 364, 883, 403, 0.67274255],
#   [940, 364, 979, 383, 0.65043974],
#   [1132, 364, 1171, 383, 0.64293796],
#   [998, 364, 1036, 383, 0.6428602],
#   [959, 364, 998, 383, 0.63834363],
#   [1017, 364, 1055, 383, 0.58826756],
#   [979, 364, 1017, 383, 0.5526528],
#   [1094, 364, 1132, 383, 0.55045795],
#   [710, 383, 767, 422, 0.53567356]],
#  [[614, 383, 652, 403, 0.76018673],
#   [1132, 326, 1151, 345, 0.68755597],
#   [633, 383, 671, 403, 0.66519177],
#   [595, 364, 671, 403, 0.6585794],
#   [729, 364, 806, 403, 0.64626443],
#   [1151, 326, 1190, 364, 0.6371616],
#   [1036, 326, 1055, 345, 0.6125134],
#   [940, 345, 979, 364, 0.5760029],
#   [1036, 326, 1075, 364, 0.5740519],
#   [940, 326, 998, 364, 0.57019824],
#   [902, 345, 940, 364, 0.5570849],
#   [633, 364, 691, 403, 0.5269452]],
#  [[691, 364, 825, 422, 0.81235325],
#   [844, 345, 902, 383, 0.753381],
#   [806, 345, 902, 403, 0.7255977],
#   [729, 364, 806, 403, 0.7252645],
#   [691, 345, 767, 383, 0.6260352],
#   [806, 364, 863, 383, 0.6071989],
#   [863, 345, 940, 383, 0.5965727],
#   [806, 345, 844, 364, 0.56020623],
#   [959, 326, 998, 345, 0.5597198],
#   [652, 345, 863, 441, 0.54672724],
#   [787, 364, 863, 403, 0.5400283],
#   [710, 403, 806, 441, 0.52705824],
#   [940, 326, 979, 345, 0.5155908],
#   [863, 326, 940, 364, 0.51024413]]]

# %%
for i in class_mapping.items():
    print(i)
# Out:
# (0, 'car\n')
# (1, 'car')
# (2, 'bg')

# %% [markdown]
# # evaluate accuracy

# %%
# eval function
def voc_eval(detpath,
             annopath,
             imagesetfile,
             classname,
             cachedir,
             ovthresh=0.5,
             use_07_metric=False):
  """
  rec, prec, ap = voc_eval(detpath,
                              annopath,
                              imagesetfile,
                              classname,
                              [ovthresh],
                              [use_07_metric])
  Top level function that does the PASCAL VOC evaluation.
  detpath: Path to detections
      detpath.format(classname) should produce the detection results file.
  annopath: Path to annotations
      annopath.format(imagename) should be the xml annotations file.
  imagesetfile: Text file containing the list of images, one image per line.
  classname: Category name (duh)
  cachedir: Directory for caching the annotations
  [ovthresh]: Overlap threshold (default = 0.5)
  [use_07_metric]: Whether to use VOC07's 11 point AP computation
      (default False)
  """
  # assumes detections are in detpath.format(classname)
  # assumes annotations are in annopath.format(imagename)
  # assumes imagesetfile is a text file with each line an image name
  # cachedir caches the annotations in a pickle file

  # first load gt
  if not os.path.isdir(cachedir):
    os.mkdir(cachedir)
  cachefile = os.path.join(cachedir, '%s_annots.pkl' % imagesetfile)
  # read list of images
  with open(imagesetfile, 'r') as f:
    lines = f.readlines()
  imagenames = [x.strip() for x in lines]

  if not os.path.isfile(cachefile):
    # load annotations
    recs = {}
    for i, imagename in enumerate(imagenames):
      recs[imagename] = parse_rec(annopath.format(imagename))
      if i % 100 == 0:
        print('Reading annotation for {:d}/{:d}'.format(
          i + 1, len(imagenames)))
    # save
    #print('Saving cached annotations to {:s}'.format(cachefile))
    #with open(cachefile, 'wb') as f:
    #  pickle.dump(recs, f)
  else:
    # load
    with open(cachefile, 'rb') as f:
      try:
        recs = pickle.load(f)
      except:
        recs = pickle.load(f, encoding='bytes')

  # extract gt objects for this class
  class_recs = {}
  npos = 0
  for imagename in imagenames:
    R = [obj for obj in recs[imagename] if obj['name'] == classname]
    bbox = np.array([x['bbox'] for x in R])
    difficult = np.array([x['difficult'] for x in R]).astype(np.bool)
    det = [False] * len(R)
    npos = npos + sum(~difficult)
    class_recs[imagename] = {'bbox': bbox,
                             'difficult': difficult,
                             'det': det}

  # read dets
  detfile = detpath.format(classname)
  with open(detfile, 'r') as f:
    lines = f.readlines()

  splitlines = [x.strip().split(' ') for x in lines]
  image_ids = [x[0] for x in splitlines]
  confidence = np.array([float(x[1]) for x in splitlines])
  BB = np.array([[float(z) for z in x[2:]] for x in splitlines])

  nd = len(image_ids)
  tp = np.zeros(nd)
  fp = np.zeros(nd)

  if BB.shape[0] > 0:
    # sort by confidence
    sorted_ind = np.argsort(-confidence)
#    sorted_scores = np.sort(-confidence)
    BB = BB[sorted_ind, :]
    image_ids = [image_ids[x] for x in sorted_ind]

    # go down dets and mark TPs and FPs
    for d in range(nd):
      id = image_ids[d][-10:-4]
      # catch bad detections
      try:
          R = class_recs[id]
      except:
        print("det not found")
        continue
        
      bb = BB[d, :].astype(float)
      ovmax = -np.inf
      BBGT = R['bbox'].astype(float)

      if BBGT.size > 0:
        # compute overlaps
        # intersection
        ixmin = np.maximum(BBGT[:, 0], bb[0])
        iymin = np.maximum(BBGT[:, 1], bb[1])
        ixmax = np.minimum(BBGT[:, 2], bb[2])
        iymax = np.minimum(BBGT[:, 3], bb[3])
        iw = np.maximum(ixmax - ixmin + 1., 0.)
        ih = np.maximum(iymax - iymin + 1., 0.)
        inters = iw * ih

        # union
        uni = ((bb[2] - bb[0] + 1.) * (bb[3] - bb[1] + 1.) +
               (BBGT[:, 2] - BBGT[:, 0] + 1.) *
               (BBGT[:, 3] - BBGT[:, 1] + 1.) - inters)

        overlaps = inters / uni
        ovmax = np.max(overlaps)
        jmax = np.argmax(overlaps)

      if ovmax > ovthresh:
        if not R['difficult'][jmax]:
          if not R['det'][jmax]:
            tp[d] = 1.
            R['det'][jmax] = 1
          else:
            fp[d] = 1.
      else:
        fp[d] = 1.

  # compute precision recall
  fp = np.cumsum(fp)
  tp = np.cumsum(tp)
  rec = tp / float(npos)
  # avoid divide by zero in case the first detection matches a difficult
  # ground truth
  prec = tp / np.maximum(tp + fp, np.finfo(np.float64).eps)
  ap = voc_ap(rec, prec, use_07_metric)

  return rec, prec, ap

# %%
pascal_classes = np.asarray(['car','car\n','bg'])
PASCAL_CLASSES = pascal_classes

# %%
pascal_classes
# Out:
# array(['car', 'car\n', 'bg'], dtype='<U4')

# %% [markdown]
# ## write out detections to evaluate on official script

# %%
def get_voc_results_file_template(cls):
        # VOCdevkit/results/VOC2007/Main/<comp_id>_det_test_aeroplane.txt
        filename = 'det_' + "val" + '_'+cls+'.txt'
        filedir = os.path.join(DEVKIT_PATH, 'results', 'VOC2007', 'Main')
        if not os.path.exists(filedir):
            os.makedirs(filedir)
        path = os.path.join(filedir, filename)
        return path


def write_voc_results_file(pascal_classes, all_boxes, image_index):
        for cls_ind, cls in enumerate(pascal_classes):
            if cls == '__background__':
                continue
            print('Writing {} VOC results file'.format(cls))
            filename = get_voc_results_file_template(cls)
            with open(filename, 'wt') as f:
                for im_ind, index in enumerate(image_index):
                    dets = np.asarray(all_boxes[cls_ind][im_ind])
                    if dets == []:
                        continue
                    # the VOCdevkit expects 1-based indices
                    for k in range(dets.shape[0]):
                        f.write('{:s} {:.3f} {:.1f} {:.1f} {:.1f} {:.1f}\n'.
                                format(index, dets[k, -1],
                                       dets[k, 0] + 1, dets[k, 1] + 1,
                                       dets[k, 2] + 1, dets[k, 3] + 1))
import xml.etree.ElementTree as ET
def parse_rec(filename):
  """ Parse a PASCAL VOC xml file """
  tree = ET.parse(filename)
  objects = []
  for obj in tree.findall('object'):
    obj_struct = {}
    obj_struct['name'] = obj.find('name').text
    obj_struct['pose'] = obj.find('pose').text
    obj_struct['truncated'] = int(obj.find('truncated').text)
    obj_struct['difficult'] = int(obj.find('difficult').text)
    bbox = obj.find('bndbox')
    obj_struct['bbox'] = [float(bbox.find('xmin').text),
                          float(bbox.find('ymin').text),
                          float(bbox.find('xmax').text),
                          float(bbox.find('ymax').text)]
    objects.append(obj_struct)

  return objects
def voc_ap(rec, prec, use_07_metric=False):
  """ ap = voc_ap(rec, prec, [use_07_metric])
  Compute VOC AP given precision and recall.
  If use_07_metric is true, uses the
  VOC 07 11 point method (default:False).
  """
  if use_07_metric:
    # 11 point metric
    ap = 0.
    for t in np.arange(0., 1.1, 0.1):
      if np.sum(rec >= t) == 0:
        p = 0
      else:
        p = np.max(prec[rec >= t])
      ap = ap + p / 11.
  else:
    # correct AP calculation
    # first append sentinel values at the end
    mrec = np.concatenate(([0.], rec, [1.]))
    mpre = np.concatenate(([0.], prec, [0.]))

    # compute the precision envelope
    for i in range(mpre.size - 1, 0, -1):
      mpre[i - 1] = np.maximum(mpre[i - 1], mpre[i])

    # to calculate area under PR curve, look for points
    # where X axis (recall) changes value
    i = np.where(mrec[1:] != mrec[:-1])[0]

    # and sum (\Delta recall) * prec
    ap = np.sum((mrec[i + 1] - mrec[i]) * mpre[i + 1])
  return ap

# %%
write_voc_results_file(pascal_classes, all_boxes, image_index)
# Out:
# Writing car VOC results file
# Writing car
#  VOC results file
# Writing bg VOC results file
# /N/u/imtiazahmad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.

# %% [markdown]
# # evaluate on VOC 2010 metric

# %%
def python_eval(output_dir='output'):
        annopath = os.path.join(
            DEVKIT_PATH,
            'VOC2007',
            'Annotations',
            '{:s}.xml')
        imagesetfile = os.path.join(
            DEVKIT_PATH,
            'VOC2007',
            'ImageSets',
            'Main',
            SET + '.txt')
        cachedir = os.path.join(DEVKIT_PATH, 'annotations_cache')
        aps = []
        # The PASCAL VOC metric changed in 2010.
        # VOC07 metric is quite old so don't use.
        use_07_metric = False
        print('VOC07 metric? ' + ('Yes' if use_07_metric else 'No'))
        if not os.path.isdir(output_dir):
            os.mkdir(output_dir)
        for i, cls in enumerate(PASCAL_CLASSES):
            if cls == 'bg':
                continue
            filename = get_voc_results_file_template(cls)
            rec, prec, ap = voc_eval(
                filename, annopath, imagesetfile, cls, cachedir, ovthresh=0.5,
                use_07_metric=use_07_metric)
            aps += [ap]
            print('AP for {} = {:.4f}'.format(cls, ap))
            with open(os.path.join(output_dir, cls + '_pr.pkl'), 'wb') as f:
                pickle.dump({'rec': rec, 'prec': prec, 'ap': ap}, f)
        print('Mean AP = {:.4f}'.format(np.mean(aps)))
        print('~~~~~~~~')
        print('Results:')
        for ap in aps:
            print('{:.3f}'.format(ap))
        print('{:.3f}'.format(np.mean(aps)))
        print('~~~~~~~~')
        print('')
        print('--------------------------------------------------------------')
        print('Results computed with the **unofficial** Python eval code.')
        print('Results should be very close to the official MATLAB eval code.')
        print('Recompute with `./tools/reval.py --matlab ...` for your paper.')
        print('-- Thanks, The Management')
        print('--------------------------------------------------------------')

# %%
# evaluate detections
python_eval()
# Out:
# VOC07 metric? No
# Reading annotation for 1/187
# Reading annotation for 101/187
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# det not found
# AP for car = 0.0000
# Reading annotation for 1/187
# Reading annotation for 101/187
# AP for car
#  = 0.0000
# Mean AP = 0.0000
# ~~~~~~~~
# Results:
# 0.000
# 0.000
# 0.000
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------

# %%
a = '../VOCdevkit/VOC2007/JPEGImages/000585.jpg'
a[-10:-4]
